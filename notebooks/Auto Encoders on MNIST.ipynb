# %%
import cPickle
import gzip

from PIL import Image
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import theano.tensor as T

import climin.stops
import climin.initialize

from IPython.core import pylabtools
pylabtools.figsize(16, 9)
from IPython.core.display import Image as image

from breze.learn import autoencoder
from breze.learn.rica import Rica
from breze.learn.utils import tile_raster_images

# %% [markdown]
# Helper functions
# ================

# %%
def scale_cols_to_unit_interval(arr):
    arr = arr.copy()
    arr -= arr.min(axis=0)
    arr /= arr.max(axis=0)
    arr *= 255
    return arr.astype('uint8')

# %% [markdown]
# Prepare Data
# ============
#
# We load the MNIST data. It is available at http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz.
#
# The inputs all lie between 0 and 1. Each target is a one of k variable.

# %%
datafile = 'mnist.pkl.gz'
# Load data.                                                                                                   

with gzip.open(datafile,'rb') as f:                                                                        
    train_set, val_set, test_set = cPickle.load(f)                                                       

X, Z = train_set                                                                                               
VX, VZ = val_set
TX, TZ = test_set

image_dims = 28, 28

# %% [markdown]
# Configuration
# =============

# %%
method = 'sparse'     # One of: basic, sparse, contractive, rica, denoising

n_features = 64
max_passes = 250

feature_dims = int(math.ceil(np.sqrt(n_features))), int(math.ceil(np.sqrt(n_features)))

batch_size = 50000
hidden_transfer = 'sigmoid'
out_transfer = 'sigmoid'
loss = 'nces'
#optimizer = 'rmsprop', {'steprate': 0.1, 'momentum': 0.0, 'decay': 0.9}
#optimizer = 'gd', {'steprate': 0.01, 'momentum': 0.95, 'momentum_type': 'nesterov'}
optimizer = 'lbfgs'
sparsify = False
par_std = 1e-1
tied_weights = True

# %% [markdown]
# Setup
# =====

# %%
losses = []

if method == 'basic':
    fe = autoencoder.AutoEncoder(X.shape[1], n_features, 
                     hidden_transfer=hidden_transfer, out_transfer=out_transfer,
                     loss=loss, 
                     batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)
elif method == 'sparse':
    sparsity_loss = 'bern_bern_kl'
        
    sparsity_target = 0.01
    c_sparsity = 2.5

    fe = autoencoder.SparseAutoEncoder(X.shape[1], n_features, 
                           hidden_transfer=hidden_transfer, out_transfer=out_transfer,
                           reconstruct_loss=loss, 
                           sparsity_loss=sparsity_loss,
                           c_sparsity=c_sparsity,
                           sparsity_target=sparsity_target,
                           batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)
elif method == 'denoising':
    c_noise = .2
    noise_type = 'blink'
    batch_size = 250

    fe = autoencoder.DenoisingAutoEncoder(X.shape[1], n_features,
                              hidden_transfer=hidden_transfer, out_transfer=out_transfer,
                              reconstruct_loss=loss, 
                              c_noise=c_noise, noise_type=noise_type,
                              batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)    

elif method == 'contractive':
    c_jacobian = 1.5
    batch_size = 250

    fe = autoencoder.ContractiveAutoEncoder(X.shape[1], n_features, 
                                hidden_transfer=hidden_transfer, out_transfer=out_transfer,
                                reconstruct_loss=loss, 
                                c_jacobian=c_jacobian,
                                batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)    
elif method == 'rica':
    c_ica = 0.1
    rica_hidden_transfer = 'identity'
    feature_transfer = 'softabs'
    
    fe = Rica(X.shape[1], n_features, c_ica=c_ica, 
              hidden_transfer=rica_hidden_transfer, feature_transfer=feature_transfer, out_transfer=out_transfer,
              loss=loss, optimizer=optimizer)

# %%
climin.initialize.randomize_normal(fe.parameters.data)

if sparsify:
    climin.initialize.sparsify_columns(fe.parameters['in_to_hidden'], sparsify)

# %% [markdown]
# Training
# ========

# %%
batches_per_pass = float(X.shape[0]) / batch_size
max_iter = int(math.ceil(max_passes * batches_per_pass))

print "max_iter", max_iter

stop = climin.stops.after_n_iterations(max_iter)
pause = climin.stops.modulo_n_iterations(batches_per_pass)

# Set up a nice printout.
keys = '#', 'loss', 'val loss'#, 'step_length'
max_len = max(len(i) for i in keys)
header = '   '.join(i.ljust(max_len) for i in keys)
print header
print '-' * len(header)


for i, info in enumerate(fe.powerfit((X,), (VX,), stop, pause)):
    losses.append((info['loss'], info['val_loss']))
    
    row = '%i' % i, '%.6f' % info['loss'], '%.6f' % info['val_loss'],# '%.6f' % info['step_length']
    print '   '.join(i.ljust(max_len) for i in row)
# Out:
# max_iter 250
# #          loss       val loss
# ------------------------------
# 0          1367.484497   1368.771484
# 1          686.899963   686.786682
# 2          578.715149   578.982422
# 3          470.286072   469.823578
# 4          283.615540   283.377197
# 5          233.924469   232.604614
# 6          225.279083   224.281464
# 7          218.381042   217.450378
# 8          208.862259   208.156860
# 9          204.066193   203.135406
# 10         199.774658   198.751068
# 11         193.957275   192.889374
# 12         191.453476   190.310684
# 13         188.674957   187.522583
# 14         185.976974   184.856674
# 15         183.291260   182.248734
# 16         181.423569   180.327133
# 17         178.359039   177.291809
# 18         176.543427   175.764114
# 19         174.395050   173.483826
# 20         171.013580   170.067520
# 21         168.068085   167.080917
# 22         166.487823   165.549866
# 23         163.363113   162.372498
# 24         161.894257   160.956589
# 25         159.292480   158.496918
# 26         157.198822   156.403442
# 27         155.049835   154.201553
# 28         152.972214   152.055450
# 29         150.715973   149.814285
# 30         149.057327   147.985413
# 31         147.391708   146.421127
# 32         146.083969   145.147461
# 33         144.643387   143.791412
# 34         143.699234   142.787750
# 35         142.390976   141.439514
# 36         141.484421   140.552368
# 37         140.398651   139.502274
# 38         139.255676   138.378891
# 39         138.074783   137.169647
# 40         137.271301   136.370621
# 41         136.320251   135.459015
# 42         135.506760   134.685196
# 43         134.878357   134.073654
# 44         133.988663   133.224762
# 45         133.385239   132.612473
# 46         132.629578   131.904541
# 47         131.960495   131.240417
# 48         131.535690   130.831070
# 49         131.035950   130.365631
# 50         130.393829   129.750580
# 51         129.872452   129.234436
# 52         129.488693   128.864914
# 53         128.922913   128.298294
# 54         128.547546   127.927376
# 55         128.163193   127.540070
# 56         127.664162   127.075089
# 57         127.378326   126.785133
# 58         127.067551   126.509071
# 59         126.692276   126.178513
# 60         126.426346   125.921638
# 61         126.046059   125.559380
# 62         125.707344   125.208145
# 63         125.431892   124.934692
# 64         125.154655   124.664398
# 65         124.885078   124.411209
# 66         124.602898   124.169388
# 67         124.407745   124.006630
# 68         124.168190   123.791542
# 69         123.975510   123.635971
# 70         123.767021   123.430229
# 71         123.561058   123.198593
# 72         123.405983   123.044495
# 73         123.179794   122.809593
# 74         122.992767   122.633987
# 75         122.819397   122.478935
# 76         122.640968   122.299088
# 77         122.484085   122.164192
# 78         122.333687   122.006828
# 79         122.154068   121.817474
# 80         122.006592   121.665344
# 81         121.826660   121.491028
# 82         121.687401   121.359489
# 83         121.560837   121.233467
# 84         121.420982   121.117058
# 85         121.288399   120.998032
# 86         121.170700   120.873268
# 87         121.044403   120.756226
# 88         120.935509   120.659149
# 89         120.812241   120.534058
# 90         120.700035   120.425140
# 91         120.598938   120.318298
# 92         120.496391   120.223709
# 93         120.393387   120.115005
# 94         120.302269   120.031174
# 95         120.207901   119.928986
# 96         120.118553   119.840988
# 97         120.040466   119.770447
# 98         119.951607   119.685524
# 99         119.875351   119.617340
# 100        119.788475   119.538757
# 101        119.702957   119.459671
# 102        119.640526   119.398903
# 103        119.567566   119.335518
# 104        119.463577   119.250412
# 105        119.407860   119.188179
# 106        119.348953   119.133163
# 107        119.257416   119.043205
# 108        119.196693   118.970901
# 109        119.108910   118.879234
# 110        119.040947   118.794563
# 111        118.961166   118.719650
# 112        118.897354   118.667496
# 113        118.816147   118.593948
# 114        118.763985   118.550407
# 115        118.674690   118.460823
# 116        118.622528   118.407730
# 117        118.566261   118.350876
# 118        118.517517   118.296455
# 119        118.428299   118.203873
# 120        118.377625   118.152145
# 121        118.324188   118.096748
# 122        118.259415   118.037933
# 123        118.183723   117.966713
# 124        118.127335   117.917450
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-8510209b777a> in <module>()
#      15
#      16
# ---> 17 for i, info in enumerate(fe.powerfit((X,), (VX,), stop, pause)):
#      18     losses.append((info['loss'], info['val_loss']))
#      19
#
# /Users/bayerj/tmp/breze-reorg/breze/breze/learn/base.pyc in powerfit(self, fit_data, eval_data, stop, report)
#     125         eval_data = [cast_array_to_local_type(i) for i in eval_data]
#     126
# --> 127         for info in self.iter_fit(*fit_data):
#     128             if report(info):
#     129                 if 'loss' not in info:
#
# /Users/bayerj/tmp/breze-reorg/breze/breze/learn/base.pyc in iter_fit(self, X)
#     272         opt = self._make_optimizer(f_loss, f_d_loss, args)
#     273
# --> 274         for i, info in enumerate(opt):
#     275             yield info
#     276
#
# /Users/bayerj/devel/climin/climin/bfgs.pyc in __iter__(self)
#     373
#     374             step_length = self.line_search.search(
# --> 375                 direction, None, args, kwargs)
#     376
#     377             step[:] = step_length * direction
#
# /Users/bayerj/devel/climin/climin/linesearch.pyc in search(self, direction, initialization, args, kwargs, loss0)
#     300             self.wrt, t, direction, loss0, grad0, direct_deriv0,
#     301             self.c1, self.c2, self.typ, self.maxiter, self.min_step_length,
# --> 302             f)
#     303
#     304         self.val = fstep
#
# /Users/bayerj/devel/climin/climin/linesearch.pyc in wolfe_line_search(x, t, d, f, g, gtd, c1, c2, LS, maxLS, tolX, funObj)
#     625         """
#     626         #Evaluate the Objective and Gradient at the Initial Step
# --> 627         f_new, g_new = funObj(x+t*d)
#     628         funEvals = 1
#     629
#
# /Users/bayerj/devel/climin/climin/linesearch.pyc in <lambda>(x)
#     288         grad0 = self.fprime(self.wrt, *args, **kwargs)
#     289         direct_deriv0 = scipy.inner(grad0, direction)
# --> 290         f = lambda x: (self.f(x, *args, **kwargs),
#     291                        self.fprime(x, *args, **kwargs))
#     292
#
# /Users/bayerj/tmp/breze-reorg/breze/breze/arch/util.pyc in wrapper(*fargs)
#      72     def wrapper(*fargs):
#      73         flat_fargs = flatten(fargs)
# ---> 74         flat_result = flat_function(*flat_fargs)
#      75         result = unflatten(exprs, flat_result)
#      76         return result
#
# /Users/bayerj/devel/Theano/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     578         t0_fn = time.time()
#     579         try:
# --> 580             outputs = self.fn()
#     581         except Exception:
#     582             if hasattr(self.fn, 'position_of_error'):
#
# KeyboardInterrupt:
# /Users/bayerj/devel/climin/climin/linesearch.py:375: ComplexWarning: Casting complex values to real discards the imaginary part
#   A[i] = [points[i, 0] ** (order - j) for j in xrange(order + 1)]
# /Users/bayerj/devel/climin/climin/linesearch.py:376: ComplexWarning: Casting complex values to real discards the imaginary part
#   b[i] = points[i, 1]
# /Users/bayerj/devel/climin/climin/linesearch.py:382: ComplexWarning: Casting complex values to real discards the imaginary part
#   for j in xrange(1, order + 1)] + [0]
# /Users/bayerj/devel/climin/climin/linesearch.py:383: ComplexWarning: Casting complex values to real discards the imaginary part
#   b[nPoints + i] = points[i, 2]

# %% [markdown]
# Reconstruction and Errors
# =========================

# %%
fig = plt.figure(figsize=((15, 5)))

img = tile_raster_images(TX[:64], image_dims, (8, 8), (1, 1))
ax0 = fig.add_subplot(131)
ax0.imshow(img, cmap=cm.binary)

f_reconstruct = fe.function(['inpt'], 'output')
TR = f_reconstruct(TX[:64])
img = tile_raster_images(TR, image_dims, (8, 8), (1, 1))
ax1 = fig.add_subplot(132)
ax1.imshow(img, cmap=cm.binary)

img = tile_raster_images(TR - TX[:64], image_dims, (8, 8), (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
ax2 = fig.add_subplot(133)
ax2.imshow(img, cmap=cm.binary)

# %% [markdown]
# Visualize Filters
# =================

# %%
filters = fe.parameters['in_to_hidden'].T

# %%
tile_size = int(math.ceil(np.sqrt(n_features))), int(math.ceil(np.sqrt(n_features)))

img = tile_raster_images(filters, image_dims, tile_size, (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
plt.imshow(img, cmap=cm.binary)
