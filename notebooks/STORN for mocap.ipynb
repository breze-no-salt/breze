# %% [markdown]
# Stochastic Recurrent Networks for human movement modelling
# ===============================================================================
#
# This notebook presents how to use stochastic recurrent networks (STORNs) for
# modelling human movement. The method has been proposed in
#
#  * Bayer, Justin, and Christian Osendorfer. "Learning Stochastic Recurrent Networks." arXiv preprint arXiv:1411.7610 (2014). [Link](arxiv.org/abs/1411.7610).
#
# It is best to revisit the paper to get a theoretical understanding of the method,
# but a quick recap follows.
#
# The model
# ---
#
# We are interested in modelling sequences $\{x_{1:T}\}_{i=1}^N$ over a vectorial
# space. To do so, we assume that the data is generated by the following model:
#
# $$h_t = f(h_{t-1}W + x_t V + z_t \hat{V} + b), \\
# x_{t+1} = g(h_t Q + \hat{b}).$$
#
# Here, $z_t \sim \mathcal{N}(0, 1)$ are **stochastic units** which help to model
# the data.
#
# As can be seen, the model is a generalisation of plain RNNs: if we set
# $\hat{V} = \mathbf{0}$, we will recover an Elman network.
# However, adding stochastic units can greatly enhance the predictive capabilities
# of our model.
#
# For one, it lets us model dependencies between the components of each $x_t$.
# Further, it can express more complicated distributions. For example, the output
# of an RNN is just a point. If we do not attach any probabilistic meanings to
# those points, they will form a Dirac distribution. However, if we integrate all
# the $z_t$ out, we can get any (yes, any) distribution--Gaussian, Laplace,
# student's T or even mixtures.
#
#
# The learning algorithm/estimator
# ---
#
# We are using a certain flavor of variational inference, namely *stochastic gradient variational Bayes* (SGVB)
# to find good paramters--that is $\{h_0, V, \hat{V}, Q, b \hat{b}\}$--for our model.
# SGVB has been described in
#
#  * Kingma, Diederik P., and Max Welling. "Auto-encoding variational bayes." arXiv preprint arXiv:1312.6114 (2013) and
#  * Rezende, Danilo Jimenez, Shakir Mohamed, and Daan Wierstra. "Stochastic backpropagation and approximate inference in deep generative models." arXiv preprint arXiv:1401.4082 (2014).
#
# but the STORN article features a quick recap. We will do a shorter one.
#
# The main idea is to minimize an upper bound on the negative log-likelihood,
# which also makes a variational approximation $q(z|x)$ close to the true posterior
# $p(z|x)$. This is done by making $q$ a parameterised model conditioned on the
# input (which is weird in the first moment); in the original papers, a neural net
# was used for that. Here, we are using (bidirectional) recurrent networks. The
# parameters of that model (the recognition model or inference model) are optimised
# jointly with the generative model above.
#
# Doing so, we get something for free: $q$ can be used for all kinds of approximate
# inference. We can perform an approximate denoising by looking at an observation $x$,
# obtaining the maximum of the approximate posterior $\text{arg max}_{\hat{z}} q(\hat{z}|x)$
# and then reconstruct $\hat{x}$ from that.
#
# We can also do impute missing values by doing so many times (using sampling from $q$
# instead of MAP) and re-feed each $\hat{x}$ into our model. This is equivalent to MCMC
# sampling from the model. If we clamp some components of $x$, we will do proper missing
# value imputation.
#
# Furthermore, there exists an efficient estimator for the NLL that does not rely on
# a costly Markov chain--something which is not available for the RBM family.
#
#
# Outline
# ---
#
# To proceed with the notebook, you will need the saltier-storn branch of Breze, which can be found here:
#
#   * https://github.com/breze-no-salt/breze/tree/saltier-storn
#
# You can install breze with the usual
#
#   ``pip install --user -e .``
#
# You will also need
# [Theano](http://deeplearning.net/software/theano/) and
# [climin](climin.readthedocs.org).

# %%
# Quite a few imports.

import cPickle
import gzip
import itertools
import math
import time

import numpy as np
import theano
import theano.tensor as T

from breze.learn.data import interleave, padzeros, split
from breze.learn import base
from breze.learn import sgvb
import breze.learn.display as D
from breze.learn.data import interleave, padzeros, split

from breze.arch.component.varprop import transfer
from breze.arch.util import WarnNaNMode

import climin.initialize
import climin.stops
import climin.mathadapt as ma

import matplotlib.pyplot as plt
from matplotlib import cm

# %matplotlib inline

theano.config.compute_test_value = 'raise'

from scipy.io import loadmat

# %% [markdown]
# Data format
# -------------------------------------------------------------------------------
#
# A word on the data format. To make things efficient, we need to put all the
# sequential data in 3D arrays. This is done by padding the shorter sequences
# with zeros. To make sure that those zeros don't interfer with learning, we will
# also use masks (that is binary matrices) with which the component wise loss
# is multiplied--that way, only the real data points will contribute to it.
#
# It will also mean longer processing times as if all sequences were of the same
# length. But it is way faster than working through each one separately.
#
# An array is thus of the form
#
#   ``(T, N, D)``
#
# where ``T`` is the number of time steps, ``N`` is the number of samples and
# ``D`` is the dimensionality of the data.
#
# The training and validation data will also be chunked into smaller sequences,
# e.g. ``100``. This is not done for the testing data. I personally do not
# believe that it affects performance much.
#
# Naming convention for data
# ---
#
# Throughout Breze, ``X`` is the training data, ``VX`` is the validation data
# and ``TX`` is the testing data. ``M``, ``VM`` and ``TM`` are the corresponding
# masks.
#
# Often, we will not chunk the testing data. In that case, the testing data is
# contained in a list called ``txs``, which contains many sequences of differing
# length of the shape ``(T, D)``. In this case, we only have a single testing
# sequence, which is why it is called ``tx``.

# %%
# This is taken from Graham Taylor--reading in the human motion data.
# https://gist.github.com/gwtaylor/2505670

def preprocess_data(Motion):
 
    n_seq = Motion.shape[1]
 
    # assume data is MIT format for now
    indx = np.r_[
        np.arange(0,6),
        np.arange(6,9),
        13,
        np.arange(18,21),
        25,
        np.arange(30,33),
        37,
        np.arange(42,45),
        49,
        np.arange(54,57),
        np.arange(60,63),
        np.arange(66,69),
        np.arange(72,75),
        np.arange(78,81),
        np.arange(84,87),
        np.arange(90,93),
        np.arange(96,99),
        np.arange(102,105)]
 
    row1 = Motion[0,0][0]
 
    offsets =   np.r_[
        row1[None,9:12],
        row1[None,15:18],
        row1[None,21:24],
        row1[None,27:30],
        row1[None,33:36],
        row1[None,39:42],
        row1[None,45:48],
        row1[None,51:54],
        row1[None,57:60],
        row1[None,63:66],
        row1[None,69:72],
        row1[None,75:78],
        row1[None,81:84],
        row1[None,87:90],
        row1[None,93:96],
        row1[None,99:102],
        row1[None,105:108]]
 
    # collapse sequences
    batchdata = np.concatenate([m[:, indx] for m in Motion.flat], axis=0)
 
    data_mean = batchdata.mean(axis=0)
    data_std = batchdata.std(axis=0)
 
    batchdata = (batchdata - data_mean) / data_std
 
    # get sequence lengths
    seqlen = [s.shape[0] for s in Motion.flat]
 
 
    return batchdata, seqlen, data_mean, data_std
 
def load_data_rather_raw(filename):
    # load data post preprocess1
    mat_dict = loadmat(filename)
    Motion = mat_dict['Motion']
 
    batchdata, seqlen, data_mean, data_std = preprocess_data(Motion)
 
    # put data into shared memory
    x = np.asarray(batchdata, dtype=theano.config.floatX)
 
    return x, seqlen, data_mean, data_std


def load_data(x, seqlen, T=200):
    xs = [x[seqlen[0] + seqlen[1]:]]
    vxs = [x[seqlen[0]:seqlen[0] + seqlen[1]]]
    tx = x[:seqlen[0]]
    
    x = split(xs, T)
    vx = split(vxs, T)
    
    X, M = padzeros(x, False, True)
    VX, VM = padzeros(vx, False, True)
    
    X, M, VX, VM = [interleave(i) for i in (X, M, VX, VM)]
    
    print M.shape
    
    M = M.mean(2)[:, :, np.newaxis]
    VM = VM.mean(2)[:, :, np.newaxis]

    print 'size of X', X.size
    print 'size of VX', VX.size

    X, VX, M, VM = [base.cast_array_to_local_type(i) for i in (X, VX, M, VM)]
    tx = base.cast_array_to_local_type(tx)

    print 'training shape', X.shape, M.shape
    print 'validation shape', VX.shape, VM.shape
    print 'testing shape', tx.shape

    return X, M, VX, VM, [tx]

x, seqlen, mean, std = load_data_rather_raw('motion.mat')
X, M, VX, VM, tx = load_data(x, seqlen, 100)

print 'Masking ratios: train %g val %g' %(M.mean(), VM.mean())
print '(That is the fraction of elements in the data arrays which do not stem from padding.)'
# Out:
# (100, 32, 49)
# size of X 156800
# size of VX 14700
# training shape (100, 32, 49) (100, 32, 1)
# validation shape (100, 3, 49) (100, 3, 1)
# testing shape (438, 49)
# Masking ratios: train 0.9775 val 0.866667
# (That is the fraction of elements in the data arrays which do not stem from padding.)

# %% [markdown]
# Model initialisation
# --------------------------------------------------------------------------------
#
# Here we initialise the model. We will comment the most important parameters in the
# cell. The hyper parameters were obtained using Bayesian optimisation via whetlab.

# %%
# Adadelta with Nesterov momentum--powerful optimiser for FD-RNNs.

optimizer = 'adadelta', {'step_rate': 1, 
                        'momentum': 0.99, 
                        'decay': 0.78, 
                        'offset': 0.00005, 
                        'step_adapt': False, 'step_rate_min': 1e-8, 'step_rate_max': 1}
# Batch sizes speed up learning for RNNs as well.
batch_size = 5

#  Amount of hidden layers of the recognition and generating model.
n_gen_layers = 1
n_recog_layers = 1

n_hiddens_recog = [174] * n_recog_layers
transfers_recog = ['tanh'] * n_recog_layers
n_hiddens_gen = [107] * n_gen_layers
transfers_gen = ['tanh'] * n_gen_layers
n_latents = 64

# Standard deviation for a Normal from which all parameters are drawn.
par_std = 0.5

# The input-to-hidden weights are drawn from this instead.
in_to_hidden_par_std = 0.000001

# After initialisation, the spectral radius of the recurrent matrices is set to this value.
spectral_radius = 4.65

# The recurrent weight matrices are restricted to only have 50 non-zero elements per row.
sparsify_rec = 50

# Similar for the input matrix.
sparsify_in = 2

# Fast dropout rates for the *generating* model.
p_dropout_inpt = .5
p_dropout_hiddens = .5
p_dropout_hidden_to_out = .12
p_dropout_shortcut = .35

reload(sgvb)

# The assumptions we make. First, we assume that the noise level 
# of the visibles is constant and somewhere around .1 everywhere.
# We assume the latent variables to follow a white Gaussian.

    
class MyStorn(sgvb.StochasticRnn,
              sgvb.GaussLatentStornMixin,
              sgvb.ConstVarGaussVisibleStornMixin):
    
    shared_std = True
    #fixed_std = theano.shared(np.ones((1,)) * .1, broadcastable=(True,)) 


# We can use a bidirectional or unidirectional recognition model. 
# Not possible for the generating model.
#m = sgvb.StochasticRnn(
m = MyStorn(
    X.shape[2],
    n_hiddens_recog, n_latents, n_hiddens_gen, transfers_recog, transfers_gen, 
    use_imp_weight=True,
    batch_size=batch_size,
    optimizer=optimizer,
    p_dropout_inpt=p_dropout_inpt,
    p_dropout_hiddens=p_dropout_hiddens,
    p_dropout_hidden_to_out=p_dropout_hidden_to_out,
    p_dropout_shortcut=p_dropout_shortcut)

infos = []
m.exprs['true_loss'] = m.exprs['loss']

m.gradient_clip_threshold = None
# Out:
# /Users/bayerj/devel/3rdparty/Theano/theano/scan_module/scan_perform_ext.py:135: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *

# %%
m.optimizer = 'rmsprop', {'step_rate': 1e-4, 
                        'momentum': 0.9, 
                        'decay': 0.78, 
                        'offset': 0.00005, 
                        'step_adapt': False, 'step_rate_min': 1e-8, 'step_rate_max': 1}

# %%
m.initialize(
    par_std=par_std, 
    par_std_in=in_to_hidden_par_std, 
    sparsify_affine=sparsify_in,    
    sparsify_rec=sparsify_rec, 
    spectral_radius=spectral_radius)


m.parameters[m.vae.gen.std][...] = 0.01

# %% [markdown]
# Training
# ===

# %%
infos = []

# %%
max_passes = 100000
max_minutes = 60
batches_per_pass = int(math.ceil(float(X.shape[1]) / m.batch_size)) if m.batch_size is not None else 1
pause = climin.stops.ModuloNIterations(batches_per_pass * 1)
#pause = climin.stops.ModuloNIterations(1)

stop = climin.stops.Any([
    climin.stops.TimeElapsed(max_minutes * 60),
    climin.stops.Patience('val_loss', 1000, grow_factor=1.1, threshold=0.0001),
    #climin.stops.not_better_than_after(30, 100),
])
    
start = time.time()
# Set up a nice printout.
header = '#', 'seconds', 'loss', 'val loss', 'std mean'
print '\t'.join(header)


for i, info in enumerate(m.powerfit((X, M), (VX, VM), stop, pause, True)):
    info['loss'] = float(info['loss'])
    info['val_loss'] = float(info['val_loss'])
    #info['test_loss'] = float(ma.scalar(test_score()))
    
    info.update({
        'time': time.time() - start,
        'std_mean': 0 #MyStorn.fixed_std.get_value()[0], 
        #'std_mean': m.parameters[m.vae.gen.std].mean(),
    })
    template = '\t'.join(
        ['%(n_iter)i', '%(time)g', '%(loss)g', '%(val_loss)g %(std_mean)g'])
    row = template % info
    print row

    filtered_info = dict(
        (k, v) for k, v in info.items()
        #if (not isinstance(v, (np.ndarray, gp.garray)) or v.size <= 1) and k not in ('args', 'kwargs'))
        if (not isinstance(v, (np.ndarray, )) or v.size <= 1) and k not in ('args', 'kwargs'))

    for key in filtered_info:
        if isinstance(filtered_info[key], np.float32):
            filtered_info[key] = float(filtered_info[key])
    filtered_info['max_grad'] = np.sqrt((info['gradient'] **
 2).sum())
    infos.append(filtered_info)
# Out:
# WARNING (theano.gof.compilelock): Overriding existing lock by dead process '13192' (I am process '13930')
# WARNING:theano.gof.compilelock:Overriding existing lock by dead process '13192' (I am process '13930')
# #	seconds	loss	val loss	std mean
# 7	46.0453	80652.6	67210.6 0
# 14	48.7147	48242.5	40212.2 0
# 21	51.3563	29730.7	24566.8 0
# 28	53.9452	19199.8	15751.1 0
# 35	56.6971	13365.9	10870.1 0
# 42	59.6048	9839.8	8054.8 0
# 49	62.2141	7471.11	6200.6 0
# 56	64.8831	5823.84	4858.79 0
# 63	67.4977	4594.58	3826.7 0
# 70	70.0915	3669.28	3054.13 0
# 77	72.6796	2963.54	2461.43 0
# 84	75.2643	2414.8	2016.42 0
# 91	77.8348	1992.89	1677.05 0
# 98	80.4352	1655.61	1400.94 0
# 105	83.0227	1385.92	1185.35 0
# 112	85.5789	1173.2	1009.14 0
# 119	88.142	1000.26	863.286 0
# 126	90.7458	856.138	738.936 0
# 133	93.3432	739	635.253 0
# 140	95.9435	642.469	553.621 0
# 147	98.541	558.559	477.068 0
# 154	101.112	490.551	417.98 0
# 161	103.971	430.936	364.077 0
# 168	106.697	382.728	321.642 0
# 175	109.277	340.447	286.048 0
# 182	111.804	303.385	252.711 0
# 189	114.331	271.482	226.668 0
# 196	116.852	244.344	203.676 0
# 203	119.469	219.997	183.123 0
# 210	122.374	199.529	165.362 0
# 217	124.927	181.367	150.436 0
# 224	127.458	165.786	136.829 0
# 231	129.964	151.471	126.681 0
# 238	132.477	138.89	117.868 0
# 245	135.016	128.572	107.703 0
# 252	137.53	118.65	101.237 0
# 259	140.05	110.033	93.5447 0
# 266	142.565	101.6	86.6612 0
# 273	145.091	94.9515	81.0322 0
# 280	147.695	88.2087	75.4814 0
# 287	150.525	82.4442	71.2623 0
# 294	153.114	77.3219	66.1394 0
# 301	155.641	72.3842	62.3673 0
# 308	158.169	67.9151	59.4541 0
# 315	160.702	63.9176	55.7531 0
# 322	163.233	60.6893	52.23 0
# 329	165.749	57.6604	50.3876 0
# 336	168.275	54.9979	49.133 0
# 343	170.81	52.0022	45.9351 0
# 350	173.335	49.8524	44.6116 0
# 357	175.889	47.7644	41.8679 0
# 364	178.404	45.8574	41.3047 0
# 371	180.917	43.8621	39.6252 0
# 378	183.715	42.2253	38.5046 0
# 385	186.321	40.5836	36.7388 0
# 392	188.888	39.1257	36.0642 0
# 399	191.415	37.934	34.13 0
# 406	193.953	36.8723	33.8304 0
# 413	196.476	35.8176	33.167 0
# 420	198.99	34.8872	31.9007 0
# 427	201.505	33.9583	31.7083 0
# 434	204.027	33.2429	30.874 0
# 441	206.542	32.4475	30.5008 0
# 448	209.064	31.7422	30.1229 0
# 455	211.584	31.3459	30.1718 0
# 462	214.102	30.739	29.2299 0
# 469	216.623	30.3226	28.705 0
# 476	219.141	29.767	28.1102 0
# 483	221.678	29.2816	27.9277 0
# 490	224.479	28.954	27.6029 0
# 497	227.136	28.6418	27.4424 0
# 504	229.76	28.2879	26.488 0
# 511	232.289	28.045	26.763 0
# 518	234.872	27.7119	26.5374 0
# 525	237.412	27.3893	26.6293 0
# 532	239.93	27.0657	26.266 0
# 539	242.445	26.8591	25.9848 0
# 546	244.968	26.5331	25.3639 0
# 553	247.523	26.328	25.2722 0
# 560	250.35	26.1389	25.0225 0
# 567	253.031	25.8964	24.7639 0
# 574	255.592	25.5829	24.5386 0
# 581	258.116	25.4504	24.5122 0
# 588	260.632	25.1243	24.3088 0
# 595	263.145	24.9447	23.9578 0
# 602	265.657	24.7303	23.7194 0
# 609	268.165	24.4934	23.8257 0
# 616	270.682	24.3873	23.6677 0
# 623	273.204	24.1422	23.5528 0
# 630	275.995	23.9111	23.3154 0
# 637	278.606	23.7348	23.0922 0
# 644	281.153	23.6072	22.827 0
# 651	283.675	23.4417	22.5378 0
# 658	286.205	23.138	22.1689 0
# 665	288.739	22.9341	22.0638 0
# 672	291.267	22.868	22.084 0
# 679	293.795	22.6647	22.1042 0
# 686	296.359	22.4996	21.6104 0
# 693	299.129	22.3152	21.7361 0
# 700	301.731	22.1481	21.3048 0
# 707	304.283	21.9848	21.2377 0
# 714	306.818	21.8762	21.0022 0
# 721	309.383	21.6875	21.1371 0
# 728	311.899	21.5281	20.9983 0
# 735	314.422	21.3421	20.6844 0
# 742	316.93	21.2059	20.5362 0
# 749	319.457	21.0894	20.3402 0
# 756	321.99	20.9386	20.3408 0
# 763	324.509	20.7352	20.3708 0
# 770	327.032	20.5739	20.26 0
# 777	329.595	20.5353	20.152 0
# 784	332.149	20.3757	19.983 0
# 791	334.902	20.1799	19.3622 0
# 798	337.595	20.0561	19.5389 0
# 805	340.118	19.9069	19.5666 0
# 812	342.651	19.8191	19.1797 0
# 819	345.184	19.7099	19.1971 0
# 826	347.722	19.6433	19.2332 0
# 833	350.253	19.4193	18.7692 0
# 840	352.788	19.3114	18.6803 0
# 847	355.33	19.1305	18.9498 0
# 854	357.876	19.1052	18.5269 0
# 861	360.391	18.9341	18.4748 0
# 868	362.902	18.7528	18.3594 0
# 875	365.433	18.7271	18.2749 0
# 882	367.964	18.5957	18.1796 0
# 889	370.496	18.4666	18.1289 0
# 896	373.056	18.3758	17.6457 0
# 903	375.83	18.2912	17.7023 0
# 910	378.415	18.1934	17.3876 0
# 917	381.03	17.9846	17.5428 0
# 924	383.606	17.9594	17.4048 0
# 931	386.133	17.7263	17.2425 0
# 938	388.641	17.704	17.3546 0
# 945	391.161	17.5755	17.1703 0
# 952	393.717	17.5208	17.2158 0
# 959	396.57	17.2594	17.1254 0
# 966	399.108	17.2972	16.6898 0
# 973	401.674	17.1796	16.5381 0
# 980	404.215	17.1245	16.4794 0
# 987	406.731	16.9583	16.4465 0
# 994	409.268	16.8884	16.421 0
# 1001	412.04	16.7355	16.3227 0
# 1008	414.687	16.6737	16.435 0
# 1015	417.224	16.5926	16.1206 0
# 1022	419.747	16.489	16.1239 0
# 1029	422.264	16.3799	16.0153 0
# 1036	424.792	16.3208	15.6901 0
# 1043	427.317	16.2713	15.6258 0
# 1050	429.871	16.1606	15.6717 0
# 1057	432.709	16.0041	15.6881 0
# 1064	435.52	15.8911	15.766 0
# 1071	438.414	15.807	15.2399 0
# 1078	441.259	15.7423	15.2767 0
# 1085	443.781	15.6551	15.5109 0
# 1092	446.292	15.6131	15.3051 0
# 1099	448.803	15.5554	15.1844 0
# 1106	451.448	15.3539	14.8414 0
# 1113	453.99	15.365	14.7515 0
# 1120	456.552	15.2103	14.6604 0
# 1127	459.139	15.1631	15.0662 0
# 1134	461.729	15.0187	14.7255 0
# 1141	464.265	15.0373	14.538 0
# 1148	466.783	14.8668	14.7538 0
# 1155	469.295	14.8386	14.5275 0
# 1162	471.869	14.7253	14.1899 0
# 1169	474.402	14.6363	14.336 0
# 1176	476.938	14.7024	14.1393 0
# 1183	479.492	14.6199	14.2476 0
# 1190	482.11	14.6062	13.8936 0
# 1197	484.656	14.4372	14.0034 0
# 1204	487.25	14.2441	13.7815 0
# 1211	489.947	14.2576	14.0734 0
# 1218	492.615	14.094	13.5943 0
# 1225	495.302	14.0466	13.8236 0
# 1232	498.025	14.1256	13.8958 0
# 1239	500.702	13.9526	13.9725 0
# 1246	503.721	13.743	13.2893 0
# 1253	506.346	13.7358	13.4278 0
# 1260	508.938	13.7695	13.2931 0
# 1267	511.547	13.6825	13.0776 0
# 1274	514.133	13.5203	13.1259 0
# 1281	516.78	13.6445	13.7072 0
# 1288	519.39	13.4565	13.2809 0
# 1295	522.004	13.374	13.0255 0
# 1302	524.642	13.3372	12.8565 0
# 1309	527.244	13.3502	13.1681 0
# 1316	529.807	13.2636	12.9874 0
# 1323	532.417	13.1256	12.8565 0
# 1330	534.977	13.1077	12.9879 0
# 1337	537.542	12.9903	12.6895 0
# 1344	540.133	12.7458	12.9582 0
# 1351	542.694	13.0026	12.7694 0
# 1358	545.241	12.8649	12.8778 0
# 1365	547.79	12.7626	12.6824 0
# 1372	550.348	12.7938	12.3586 0
# 1379	552.905	12.5565	12.5687 0
# 1386	555.62	12.6513	12.5631 0
# 1393	558.485	12.5334	12.4667 0
# 1400	561.114	12.4537	12.4975 0
# 1407	563.811	12.3331	12.4501 0
# 1414	566.455	12.4566	12.3441 0
# 1421	569.156	12.264	12.2806 0
# 1428	571.81	12.3384	12.211 0
# 1435	574.463	12.1914	11.8988 0
# 1442	577.032	12.1571	12.1082 0
# 1449	579.624	12.1986	11.9746 0
# 1456	582.194	12.1114	12.1217 0
# 1463	584.819	11.8701	12.0214 0
# 1470	587.448	11.9197	11.8193 0
# 1477	590	11.7994	12.2238 0
# 1484	592.604	11.7921	11.9251 0
# 1491	595.273	11.6282	11.6588 0
# 1498	597.955	11.6069	11.9058 0
# 1505	600.544	11.6267	11.8354 0
# 1512	603.124	11.5698	11.5986 0
# 1519	605.712	11.5264	11.302 0
# 1526	608.351	11.4056	11.4945 0
# 1533	611.133	11.4554	11.5612 0
# 1540	613.73	11.299	11.6182 0
# 1547	616.364	11.2723	10.9666 0
# 1554	618.918	11.2932	11.556 0
# 1561	621.496	11.1523	11.682 0
# 1568	624.083	11.1548	11.0488 0
# 1575	626.622	11.0816	11.5436 0
# 1582	629.188	11.1662	11.2005 0
# 1589	631.735	11.0024	11.0123 0
# 1596	634.286	10.812	11.5721 0
# 1603	636.825	10.833	11.1334 0
# 1610	639.349	10.713	11.0784 0
# 1617	641.886	10.8663	11.4612 0
# 1624	644.427	10.6521	11.1091 0
# 1631	646.983	10.6707	11.1958 0
# 1638	649.547	10.6088	11.0222 0
# 1645	652.097	10.6775	10.7158 0
# 1652	654.694	10.4733	10.7496 0
# 1659	657.265	10.3777	10.8888 0
# 1666	659.818	10.3098	10.8766 0
# 1673	662.378	10.3786	10.9719 0
# 1680	664.936	10.3945	10.6451 0
# 1687	667.482	10.3166	10.6986 0
# 1694	670.05	10.2744	11.154 0
# 1701	672.646	10.2005	10.7301 0
# 1708	675.235	10.1383	10.0876 0
# 1715	677.79	10.0631	11.0532 0
# 1722	680.404	9.98066	10.5058 0
# 1729	682.943	9.94779	10.9706 0
# 1736	685.521	10.0273	10.7893 0
# 1743	688.107	9.85775	10.6702 0
# 1750	690.717	9.76855	10.9663 0
# 1757	693.324	9.80752	10.7078 0
# 1764	695.945	9.72798	10.951 0
# 1771	698.554	9.73256	10.6183 0
# 1778	701.126	9.62884	10.5497 0
# 1785	703.673	9.67165	10.5115 0
# 1792	706.209	9.67974	10.4374 0
# 1799	708.779	9.53863	10.1727 0
# 1806	711.317	9.60939	10.7832 0
# 1813	713.86	9.46331	10.07 0
# 1820	716.4	9.40424	10.4313 0
# 1827	718.946	9.3448	10.463 0
# 1834	721.508	9.44384	10.1837 0
# 1841	724.109	9.25571	10.4639 0
# 1848	726.715	9.26803	9.71398 0
# 1855	729.267	9.07869	10.0622 0
# 1862	731.885	9.23835	10.1797 0
# 1869	734.463	9.03519	10.2784 0
# 1876	737.105	8.98688	9.97455 0
# 1883	739.821	9.04128	10.4312 0
# 1890	742.387	8.9418	10.4247 0
# 1897	744.984	8.92685	10.0082 0
# 1904	747.577	8.9732	9.92224 0
# 1911	750.187	8.84385	10.0622 0
# 1918	752.97	8.80007	10.2953 0
# 1925	755.592	8.83866	10.0351 0
# 1932	758.422	8.73931	9.72915 0
# 1939	761.025	8.65765	9.8619 0
# 1946	763.566	8.61553	9.76371 0
# 1953	766.125	8.70201	9.94082 0
# 1960	768.731	8.56699	10.385 0
# 1967	771.31	8.66912	10.0126 0
# 1974	774.012	8.5857	9.84838 0
# 1981	776.641	8.54288	10.0827 0
# 1988	779.183	8.39257	10.0658 0
# 1995	781.733	8.34296	10.6923 0
# 2002	784.381	8.46222	9.85194 0
# 2009	787.163	8.13383	9.50865 0
# 2016	789.936	8.17075	9.89081 0
# 2023	792.678	8.30649	10.2528 0
# 2030	795.37	7.99626	9.65252 0
# 2037	798.11	8.28289	10.423 0
# 2044	800.863	8.1051	10.2905 0
# 2051	803.486	8.13889	9.76615 0
# 2058	806.076	8.13588	9.65815 0
# 2065	808.67	8.00959	9.76524 0
# 2072	811.214	8.09664	9.43757 0
# 2079	813.727	8.10184	9.68633 0
# 2086	816.3	7.86903	9.44247 0
# 2093	818.84	7.93859	9.44983 0
# 2100	821.366	7.81511	9.69352 0
# 2107	823.914	7.87833	9.46926 0
# 2114	826.47	7.91697	9.28763 0
# 2121	828.999	7.74366	9.46297 0
# 2128	831.517	7.83654	9.62148 0
# 2135	834.041	7.77642	9.25429 0
# 2142	836.64	7.75387	9.595 0
# 2149	839.249	7.59705	9.36891 0
# 2156	841.857	7.50187	9.73909 0
# 2163	844.417	7.59212	9.76487 0
# 2170	846.988	7.40576	9.54018 0
# 2177	849.515	7.49834	9.22542 0
# 2184	852.05	7.47626	9.30896 0
# 2191	854.612	7.38667	9.60262 0
# 2198	857.195	7.35923	9.10391 0
# 2205	859.739	7.41772	9.26491 0
# 2212	862.288	7.36317	9.01093 0
# 2219	864.807	7.29707	9.24395 0
# 2226	867.354	7.21872	9.61474 0
# 2233	869.908	7.33917	9.18004 0
# 2240	872.459	7.23478	9.60881 0
# 2247	874.983	7.24526	9.07896 0
# 2254	877.542	7.25714	9.06052 0
# 2261	880.082	7.11478	9.72675 0
# 2268	882.623	7.04331	8.91284 0
# 2275	885.166	7.09483	9.17451 0
# 2282	887.701	7.09352	8.79413 0
# 2289	890.233	7.01777	9.80898 0
# 2296	892.761	6.93472	9.10898 0
# 2303	895.309	6.89605	9.44642 0
# 2310	897.835	6.74684	9.13079 0
# 2317	900.353	6.93101	9.07386 0
# 2324	902.898	6.75212	9.01036 0
# 2331	905.433	6.76696	9.13743 0
# 2338	908.005	6.76329	8.57179 0
# 2345	910.548	6.70693	8.92362 0
# 2352	913.082	6.73219	9.13146 0
# 2359	915.614	6.76409	9.13007 0
# 2366	918.16	6.64933	9.03483 0
# 2373	920.693	6.4852	9.13433 0
# 2380	923.252	6.59687	8.92191 0
# 2387	925.823	6.51827	8.52581 0
# 2394	928.35	6.42652	8.94167 0
# 2401	930.864	6.50163	9.04985 0
# 2408	933.375	6.35838	8.84495 0
# 2415	935.889	6.51192	8.89387 0
# 2422	938.415	6.40981	8.92498 0
# 2429	940.979	6.2866	8.5558 0
# 2436	943.515	6.35077	8.9552 0
# 2443	946.092	6.37699	9.12991 0
# 2450	948.674	6.27343	8.59022 0
# 2457	951.202	6.28114	8.52433 0
# 2464	953.739	6.27039	8.95369 0
# 2471	956.3	6.15777	8.75954 0
# 2478	958.853	6.25542	9.09796 0
# 2485	961.373	6.07554	8.6628 0
# 2492	963.898	6.05002	8.25849 0
# 2499	966.447	6.04188	8.84732 0
# 2506	968.955	6.00768	9.04252 0
# 2513	971.518	6.03108	8.67043 0
# 2520	974.083	6.07606	8.27236 0
# 2527	976.621	5.92658	8.55488 0
# 2534	979.165	6.01074	8.18187 0
# 2541	981.737	5.8979	8.66507 0
# 2548	984.261	5.70329	8.33858 0
# 2555	986.804	5.74402	8.48236 0
# 2562	989.337	5.8848	8.4406 0
# 2569	991.867	5.78357	8.63032 0
# 2576	994.41	5.8272	8.96083 0
# 2583	996.947	5.73895	7.88031 0
# 2590	999.465	5.73465	8.21116 0
# 2597	1001.98	5.60822	8.3316 0
# 2604	1004.52	5.69395	7.93496 0
# 2611	1007.04	5.59873	7.86155 0
# 2618	1009.57	5.599	8.36573 0
# 2625	1012.1	5.46422	8.23458 0
# 2632	1014.61	5.41017	7.99854 0
# 2639	1017.17	5.50995	8.6282 0
# 2646	1019.74	5.44922	8.90313 0
# 2653	1022.25	5.24088	8.25327 0
# 2660	1024.77	5.50183	8.04666 0
# 2667	1027.3	5.40199	7.68249 0
# 2674	1029.85	5.45265	7.55537 0
# 2681	1032.42	5.25394	8.42701 0
# 2688	1034.95	5.33052	8.35882 0
# 2695	1037.48	5.29994	8.01186 0
# 2702	1040.01	5.15104	7.82797 0
# 2709	1042.55	5.30568	7.45383 0
# 2716	1045.11	5.13634	7.79095 0
# 2723	1047.72	5.21779	8.08775 0
# 2730	1050.29	5.26944	7.78131 0
# 2737	1052.87	5.14169	7.96021 0
# 2744	1055.53	4.99247	8.33004 0
# 2751	1058.1	5.23522	7.43632 0
# 2758	1060.69	5.0324	8.43578 0
# 2765	1063.32	4.86711	8.87768 0
# 2772	1065.91	4.90697	7.91768 0
# 2779	1068.51	4.98722	8.01676 0
# 2786	1071.07	4.99948	8.13927 0
# 2793	1073.6	5.14237	8.11179 0
# 2800	1076.16	4.88075	8.13425 0
# 2807	1078.72	4.90135	8.3839 0
# 2814	1081.29	4.74611	8.31486 0
# 2821	1083.88	4.71522	8.38412 0
# 2828	1086.49	4.63939	8.29438 0
# 2835	1089.08	4.69705	7.54545 0
# 2842	1091.77	4.75973	7.90807 0
# 2849	1094.43	4.71613	7.3374 0
# 2856	1097.11	4.54995	7.66457 0
# 2863	1099.78	4.51517	8.1248 0
# 2870	1102.47	4.50383	8.43561 0
# 2877	1105.15	4.42002	8.12964 0
# 2884	1107.89	4.57622	7.51677 0
# 2891	1110.53	4.57457	7.50286 0
# 2898	1113.16	4.45992	8.02221 0
# 2905	1115.79	4.47347	7.47077 0
# 2912	1118.46	4.45928	7.95669 0
# 2919	1121.11	4.31096	7.23345 0
# 2926	1123.73	4.27059	7.59076 0
# 2933	1126.27	4.33048	7.88343 0
# 2940	1128.81	4.23203	7.6614 0
# 2947	1131.36	4.3786	7.50017 0
# 2954	1133.9	4.21376	7.95241 0
# 2961	1136.47	4.20823	7.3995 0
# 2968	1139.05	4.20483	7.68873 0
# 2975	1141.62	4.15316	8.0225 0
# 2982	1144.23	4.22397	7.37811 0
# 2989	1147	4.14851	7.49232 0
# 2996	1149.72	4.05677	7.62455 0
# 3003	1152.36	4.11688	7.7797 0
# 3010	1154.93	3.8938	7.49085 0
# 3017	1157.47	4.05593	7.94252 0
# 3024	1160.06	3.92928	7.9326 0
# 3031	1162.64	3.94405	7.74381 0
# 3038	1165.16	3.94642	8.046 0
# 3045	1167.68	3.93087	7.18554 0
# 3052	1170.2	3.9954	6.79004 0
# 3059	1172.71	3.75807	7.85661 0
# 3066	1175.23	3.78336	7.49467 0
# 3073	1177.78	3.75232	7.60353 0
# 3080	1180.37	3.7924	7.23995 0
# 3087	1182.95	3.69297	7.18688 0
# 3094	1185.48	3.71203	8.30884 0
# 3101	1187.99	3.58913	8.07768 0
# 3108	1190.51	3.69989	7.74964 0
# 3115	1193.04	3.79583	7.59993 0
# 3122	1195.57	3.59072	6.97413 0
# 3129	1198.1	3.55289	7.55789 0
# 3136	1200.7	3.6165	7.55643 0
# 3143	1203.31	3.55717	7.60554 0
# 3150	1205.83	3.64747	7.55123 0
# 3157	1208.36	3.50606	7.4546 0
# 3164	1210.92	3.52191	7.2223 0
# 3171	1213.46	3.44199	7.63973 0
# 3178	1216.12	3.50469	7.31948 0
# 3185	1218.67	3.46922	7.20437 0
# 3192	1221.23	3.48552	7.50839 0
# 3199	1223.78	3.45377	7.84737 0
# 3206	1226.33	3.4052	7.49304 0
# 3213	1228.87	3.21955	7.35211 0
# 3220	1231.41	3.18907	7.41981 0
# 3227	1233.95	3.26078	7.17491 0
# 3234	1236.49	3.23832	6.99767 0
# 3241	1239.05	3.3061	7.46015 0
# 3248	1241.6	3.35576	7.22738 0
# 3255	1244.21	3.16915	7.85287 0
# 3262	1246.76	3.20896	6.89056 0
# 3269	1249.29	3.29119	7.09464 0
# 3276	1251.85	3.08532	7.53941 0
# 3283	1254.36	3.09453	6.8307 0
# 3290	1256.94	3.04727	6.75044 0
# 3297	1259.49	3.05794	7.50974 0
# 3304	1262.04	3.10431	7.32241 0
# 3311	1264.59	3.12149	6.96755 0
# 3318	1267.14	2.97135	7.34301 0
# 3325	1269.67	2.96232	7.55307 0
# 3332	1272.23	2.88252	7.50482 0
# 3339	1274.81	2.86224	7.0989 0
# 3346	1277.41	2.8852	7.17574 0
# 3353	1279.95	2.93989	7.31815 0
# 3360	1282.48	2.69142	7.54663 0
# 3367	1285	2.8002	7.14614 0
# 3374	1287.53	2.86032	7.1659 0
# 3381	1290.07	2.87536	7.74723 0
# 3388	1292.6	2.7049	7.29173 0
# 3395	1295.14	2.84419	7.57726 0
# 3402	1297.7	2.63633	6.6664 0
# 3409	1300.28	2.6435	7.24931 0
# 3416	1302.94	2.66698	7.58698 0
# 3423	1305.62	2.70227	6.79025 0
# 3430	1308.14	2.51811	7.65095 0
# 3437	1310.69	2.71891	7.27899 0
# 3444	1313.22	2.61749	7.32796 0
# 3451	1315.73	2.46541	7.14249 0
# 3458	1318.26	2.57726	7.33537 0
# 3465	1320.85	2.37916	7.52503 0
# 3472	1323.41	2.51356	6.98194 0
# 3479	1325.99	2.62122	6.68978 0
# 3486	1328.52	2.32943	6.90484 0
# 3493	1331.12	2.38659	7.0774 0
# 3500	1333.95	2.39235	7.3105 0
# 3507	1336.75	2.38669	7.17215 0
# 3514	1339.32	2.30496	7.70225 0
# 3521	1341.88	2.30138	7.43482 0
# 3528	1344.44	2.28256	6.92678 0
# 3535	1347.03	2.21215	7.35562 0
# 3542	1349.81	2.19895	6.81636 0
# 3549	1352.37	2.2529	7.54764 0
# 3556	1354.96	2.24596	7.75944 0
# 3563	1357.51	2.25783	7.27562 0
# 3570	1360.09	2.07441	6.81519 0
# 3577	1362.73	2.0176	6.75749 0
# 3584	1365.35	2.1798	7.24 0
# 3591	1367.91	2.1208	7.38739 0
# 3598	1370.49	1.86204	7.12534 0
# 3605	1373.07	2.06769	7.1792 0
# 3612	1375.61	2.07184	6.84635 0
# 3619	1378.21	1.98951	6.64574 0
# 3626	1380.77	2.0345	6.87171 0
# 3633	1383.3	1.91919	6.8923 0
# 3640	1385.82	1.90426	7.12314 0
# 3647	1388.41	1.96938	7.09716 0
# 3654	1390.94	2.02554	7.38861 0
# 3661	1393.54	1.97735	7.1823 0
# 3668	1396.11	1.93027	7.24298 0
# 3675	1398.79	1.81988	6.62404 0
# 3682	1401.66	1.59369	6.66257 0
# 3689	1404.21	1.76901	6.82905 0
# 3696	1406.8	1.86826	6.96428 0
# 3703	1409.48	1.72691	6.82734 0
# 3710	1412.09	1.71583	6.88573 0
# 3717	1414.65	1.76892	7.69827 0
# 3724	1417.16	1.60636	6.83817 0
# 3731	1419.68	1.71912	7.10051 0
# 3738	1422.22	1.70899	6.80409 0
# 3745	1424.76	1.4649	6.62714 0
# 3752	1427.29	1.68871	6.93768 0
# 3759	1429.82	1.77679	6.7022 0
# 3766	1432.36	1.60521	6.94699 0
# 3773	1434.93	1.55755	7.30673 0
# 3780	1437.47	1.5011	6.64664 0
# 3787	1439.98	1.65277	6.98565 0
# 3794	1442.53	1.47559	7.38829 0
# 3801	1445.09	1.40488	7.14843 0
# 3808	1447.61	1.57787	7.2414 0
# 3815	1450.14	1.47136	7.09164 0
# 3822	1452.7	1.41455	7.15485 0
# 3829	1455.28	1.36408	7.24804 0
# 3836	1457.93	1.33689	7.17337 0
# 3843	1460.57	1.40665	7.21206 0
# 3850	1463.18	1.36162	7.14266 0
# 3857	1465.84	1.32345	7.25041 0
# 3864	1468.41	1.34854	6.58235 0
# 3871	1470.96	1.33859	6.58778 0
# 3878	1473.47	1.15487	6.13764 0
# 3885	1476	0.956433	6.93577 0
# 3892	1478.54	1.12789	6.81282 0
# 3899	1481.06	1.139	7.12118 0
# 3906	1483.6	1.11858	6.76737 0
# 3913	1486.12	1.20522	7.10841 0
# 3920	1488.65	1.20008	7.37026 0
# 3927	1491.16	1.03914	6.84109 0
# 3934	1493.69	1.16185	6.74561 0
# 3941	1496.22	1.19007	6.82435 0
# 3948	1498.79	1.04352	7.61121 0
# 3955	1501.43	0.947331	7.09463 0
# 3962	1504.04	1.10277	6.56041 0
# 3969	1506.65	1.0177	7.11642 0
# 3976	1509.24	0.985532	6.13837 0
# 3983	1511.75	0.988011	6.6849 0
# 3990	1514.27	0.928392	7.0674 0
# 3997	1516.79	1.02079	6.89772 0
# 4004	1519.31	0.876826	6.57957 0
# 4011	1521.84	0.990937	6.81788 0
# 4018	1524.44	0.826829	7.3408 0
# 4025	1527.07	0.919279	6.32374 0
# 4032	1529.7	0.848199	7.57839 0
# 4039	1532.28	0.93309	7.61313 0
# 4046	1534.88	0.649971	6.38319 0
# 4053	1537.4	0.839717	6.92107 0
# 4060	1539.92	0.617252	6.47544 0
# 4067	1542.44	0.948617	6.99897 0
# 4074	1544.99	0.72571	6.82114 0
# 4081	1547.54	0.68375	7.22461 0
# 4088	1550.08	0.764496	6.36919 0
# 4095	1552.62	0.807574	7.73343 0
# 4102	1555.21	0.67872	6.56727 0
# 4109	1557.73	0.596131	7.2904 0
# 4116	1560.27	0.676808	7.13952 0
# 4123	1562.85	0.526248	6.55907 0
# 4130	1565.47	0.593171	7.06158 0
# 4137	1568.11	0.661324	6.93856 0
# 4144	1570.73	0.531184	6.41546 0
# 4151	1573.32	0.541518	6.9602 0
# 4158	1575.95	0.579192	6.98145 0
# 4165	1578.51	0.485993	7.16216 0
# 4172	1581.14	0.512619	7.69468 0
# 4179	1583.86	0.48355	7.45357 0
# 4186	1586.54	0.431503	7.35761 0
# 4193	1589.17	0.240058	7.04651 0
# 4200	1591.97	0.453591	6.70532 0
# 4207	1594.62	0.440182	7.26154 0
# 4214	1597.44	0.233456	6.59467 0
# 4221	1600.38	0.323002	7.14188 0
# 4228	1603.29	0.340235	6.80207 0
# 4235	1606.09	0.276687	8.06108 0
# 4242	1608.81	0.186575	6.70071 0
# 4249	1611.48	0.349256	7.09231 0
# 4256	1614.03	0.122014	6.33475 0
# 4263	1616.6	0.387305	7.30273 0
# 4270	1619.21	0.0980096	7.44109 0
# /Users/bayerj/devel/climin/climin/util.py:150: UserWarning: Argument named offset is not expected by <class 'climin.rmsprop.RmsProp'>
#   % (i, klass))
# /Users/bayerj/devel/climin/climin/util.py:150: UserWarning: Argument named f is not expected by <class 'climin.rmsprop.RmsProp'>
#   % (i, klass))

# %%
f_loss = m.function(['inpt', 'imp_weight'], 'loss')

# %%
# Recover best parameters.
m.parameters.data[...] = info['best_pars']

# %%
def f(x):
    x = np.array(x).astype('float32')
    MyStorn.fixed_std.set_value(np.array([x]))
    return m.estimate_nll(VX)

# %%
cands = np.linspace(1e-8, 1, 20)
bounds = (f(i) for i in cands)

best, best_cand = float('inf'), 0
for bound, cand in itertools.izip(bounds, cands):
    print bound, cand
    if bound < best:
        best, best_cand = bound, cand
print '-->', best_cand, best
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-403d4844fdda> in <module>()
#       3
#       4 best, best_cand = float('inf'), 0
# ----> 5 for bound, cand in itertools.izip(bounds, cands):
#       6     print bound, cand
#       7     if bound < best:
#
# <ipython-input-42-403d4844fdda> in <genexpr>((i,))
#       1 cands = np.linspace(1e-8, 1, 20)
# ----> 2 bounds = (f(i) for i in cands)
#       3
#       4 best, best_cand = float('inf'), 0
#       5 for bound, cand in itertools.izip(bounds, cands):
#
# <ipython-input-41-daed5d42663d> in f(x)
#       1 def f(x):
#       2     x = np.array(x).astype('float32')
# ----> 3     MyStorn.fixed_std.set_value(np.array([x]))
#       4     return m.estimate_nll(VX)
#
# AttributeError: 'NoneType' object has no attribute 'set_value'

# %%
MyStorn.fixed_std.set_value(np.array([best_cand]))

# %% [markdown]
# Evaluation
# ---
#
# The values for the training/validation do *not* respect the importance weights.

# %%
print 'Bound %.2f    NLL estimate %g for training' % (f_loss(X, M), m.estimate_nll(X, 5))
print 'Bound %.2f    NLL estimate %g for validation' % (f_loss(VX, VM), m.estimate_nll(VX, 5))
print 'Bound %.2f    NLL estimate %g for testing' % (f_loss(tx[0][:, np.newaxis], np.ones_like(tx[0][:, np.newaxis, :1])), m.estimate_nll(tx[0][:, np.newaxis], 5))
# Out:
# Bound 1.12    NLL estimate 1.39127 for training
# Bound 6.70    NLL estimate 7.11048 for validation
# Bound 20.67    NLL estimate 19.9213 for testing

# %% [markdown]
# ## Learning curves

# %%
start = 0
plt.plot([(i['loss']) for i in infos[start:]])
plt.plot([i['val_loss'] for i in infos[start:]])
#plt.plot([i['max_grad'] / 200. for i in infos[200:]])

# %% [markdown]
# ## Sampling

# %%
prefix_length = 20
sample_length = 50
x = np.concatenate([VX[:, :1]] * 50, axis=1)
S = m.sample(sample_length, x[:prefix_length], visible_map=True)
# Out:
# /Users/bayerj/devel/breze/breze/arch/util.py:577: UserWarning: theano.function was asked to create a function computing outputs given certain inputs, but the provided input variable at index 0 is not part of the computational graph needed to compute the outputs: parameters.
# To make this warning into an error, you can pass the parameter on_unused_input='raise' to theano.function. To disable it completely, use on_unused_input='ignore'.
#   on_unused_input=on_unused_input, updates=updates)

# %%
angle_idxs = range(49)
sample_idx = 0
xs = np.arange(prefix_length + sample_length - 1)

fig, axs = plt.subplots(7, 7, figsize=(16, 9))

axs = list(itertools.chain(*axs))
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    
    _ = ax.plot(xs[prefix_length:], S[:, :, i], 'k', alpha=.2)
    _ = ax.axhline(0)
    _ = ax.plot(VX[:, 0, i], label='stimulus')

axs[-1].plot([0, 0], [0, 0], 'k', label='sample')
axs[-1].set_ylim([-100, -99])
axs[-1].set_xlim([-100, -99])
axs[-1].legend(loc=0)

#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

plt.savefig('/Users/bayerj/Desktop/stimulus-sampling.pdf', bbox_inches='tight')

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Probabilistic

# %%
rng = T.shared_randomstreams.RandomStreams()
predict_expr_noisy = theano.clone(m.vae.output, 
                            {m.vae.sample: rng.normal(m.vae.sample.shape)})
f_predict_noisy = m.function(['inpt'], predict_expr_noisy)

# %%
x = tx[0][:, np.newaxis]
ys = [f_predict_noisy(x)[:, :1, :49] for i in range(10)]
y = np.mean(ys, axis=0)

# %%
print 'approx prob prediction', ((y - x) ** 2).mean(0).sum()

# %% [markdown]
# ### Latent Mode

# %%
f_predict = m.function(['inpt'], 'output', givens={m.vae.sample: T.zeros_like(m.vae.sample)})

# %%
x = tx[0][:, np.newaxis]
y = f_predict(x)[:, :1, :49]

# %%
print 'map prediction', ((y - x) ** 2).mean(0).sum()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 16))

axs = list(itertools.chain(*axs))[:49]
for i, ax in enumerate(axs):
    ax.plot(x[:, 0, [i]], label='true', linewidth=1)
    ax.plot(y[:, 0, [i]], label='predicted', linewidth=1)
    ax.plot(abs(x - y)[:, 0, [i]] - 5, 'k.', label='|residual|')
    ax.set_ylim([-5, 3])
    #ax.set_title('dimension %i' % i)
    ax.set_yticks([])
    ax.set_xticks([])

axs[0].legend()

# %% [markdown]
# Reconstruction
# ---

# %%
f_reconstruct = m.function(['inpt'], 'output')

# %%
R = f_reconstruct(X)[:, :, :49]

# %%
fig, axs = plt.subplots(7, 7, figsize=(16, 16))
start, stop = 0, -1

axs = list(itertools.chain(*axs))[:49]
for i, ax in enumerate(axs):
    ax.plot(X[start:stop, 0, [i]], label='truth', linewidth=1)
    ax.plot(R[start:stop, 0, [i]], label='reconstruction', linewidth=1)
    #ax.plot(noisy[start:stop, 0, [i]], label='noisy', linewidth=1)
    #ax.plot(denoised[start:stop, 0, [i]], label='denoised', linewidth=2, color='k')
    #ax.plot(abs(noisy[:, :, :49] - X)[:, 0, [i]] - 5, 'r.', label='|residual noisy|')
    #ax.plot(abs(denoised[:, :, :49] - X)[:, 0, [i]] - 5, 'b.', label='|residual denoised|')
    ax.set_ylim([-5, 3])
    #ax.set_title('dimension %i' % i)
    ax.set_yticks([])
    ax.set_xticks([])

axs[0].legend()

# %% [markdown]
# Missing Value Imputation
# ---

# %%
sample_map = m.vae.latent[:, :, :n_latents]
gen_inpt = T.concatenate([sample_map, m.vae.condition], axis=2)

map_recons_exprs = theano.clone(m.exprs['output'], 
                                {m.vae.sample: sample_map})
f_map_recons = m.function(['inpt'], map_recons_exprs)

# %%
def map_impute(start, to_impute_idxs, n_steps=10):
    denoised = start.copy()
    denoised[to_impute_idxs] = np.random.standard_normal(denoised[to_impute_idxs].shape)
    noisy = denoised.copy()
    
    for i in range(n_steps):
        reconstructed = f_map_recons(denoised)
        denoised[to_impute_idxs] = reconstructed[:, :, :49][to_impute_idxs]
    return noisy, denoised

# %%
clean = VX[:, :1]
mask = np.zeros_like(clean).astype('uint8')
mask[30:40][...] = 1
to_impute_idxs = np.where(mask)
#noised[to_impute_idxs] = np.random.standard_normal(noised[to_impute_idxs].shape) * 1

noisy, denoised = map_impute(clean, to_impute_idxs, 100)

# %%
angle_idxs = range(49)
sample = 0

fig, axs = plt.subplots(7, 7, figsize=(16, 9))

xs = np.arange(X.shape[0])
axs = list(itertools.chain(*axs))
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)

    _ = ax.plot(xs[to_impute_idxs[0]], noisy[to_impute_idxs[0], 0, i], 'r-', linewidth=1, label='noisy', alpha=.3)
    _ = ax.plot(xs[to_impute_idxs[0]], denoised[to_impute_idxs[0], 0, i], 'k-', linewidth=1, label='imputed')
    _ = ax.plot(xs, clean[:, 0, i], 'b-', linewidth=1, label='truth', alpha=.5)

axs[-1].set_ylim([-100, -99])
axs[-1].set_xlim([-100, -99])
axs[-1].legend(loc=0)

#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

plt.savefig('/Users/bayerj/Desktop/imputed.pdf', bbox_inches='tight')

# %% [markdown]
# Latent trajectories
# ---

# %%
f_latent = m.function(['inpt'], m.vae.latent)

# %%
L = f_latent(VX[:, :10])
Lm, Ls = L[:, :, :m.n_latent], L[:, :, m.n_latent:]

# %%
fig, axs = plt.subplots(5, 5, figsize=(16, 16))

def plot_latent_trajectory(ax, mean, vr):
        ax.plot(mean, 'k+-')
        #ax.plot(mean + std, 'k--')
        #ax.plot(mean - std, 'k--')
        
        x = np.arange(mean.shape[0])
        ax.fill(
            np.concatenate([x, x[::-1]]),
            np.concatenate([mean - vr, (mean + vr)[::-1]]),
            alpha=.5, fc='b', ec='None')
        ax.set_xticks([])
        ax.set_yticks([-1, 0, 1])

axs_flat = itertools.chain(*axs)

#active = [6, 7, 9, 20, 26, 32, 37, 60]
active = range(64)

for i, ax in enumerate(axs_flat):
    try:
        plot_latent_trajectory(ax, Lm[:, 0, i], Ls[:, 0, i])
    except IndexError:
        break
