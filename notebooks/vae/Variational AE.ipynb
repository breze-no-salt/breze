# %%
import cPickle
import gzip

from breze.learn.data import one_hot
from breze.learn.base import cast_array_to_local_type
from breze.learn.utils import tile_raster_images

import climin.stops
import climin.initialize

import vae
reload(vae)

from matplotlib import pyplot as plt
from matplotlib import cm

import numpy as np

import fasttsne

from IPython.html import widgets
# %matplotlib inline

# %%
datafile = '../mnist.pkl.gz'
# Load data.                                                                                                   

with gzip.open(datafile,'rb') as f:                                                                        
    train_set, val_set, test_set = cPickle.load(f)                                                       

X, Z = train_set                                                                                               
VX, VZ = val_set
TX, TZ = test_set

Z = one_hot(Z, 10)
VZ = one_hot(VZ, 10)
TZ = one_hot(TZ, 10)

image_dims = 28, 28

X, Z, VX, VZ, TX, TZ = [cast_array_to_local_type(i) for i in (X, Z, VX,VZ, TX, TZ)]

# %%
fig, ax = plt.subplots(figsize=(9, 9))

img = tile_raster_images(X[:64], image_dims, (8, 8), (1, 1))
ax.imshow(img, cmap=cm.binary)

# %%
reload(vae)
batch_size = 200
#optimizer = 'rmsprop', {'step_rate': 1e-3, 'momentum': 0.95, 'decay': .95, 'offset': 1e-6}
optimizer = 'adadelta', {'step_rate': 1, 'momentum': 0.0, 'decay': .95, 'offset': 1e-6}
m = vae.VariationalAutoEncoder(X.shape[1], [200, 200, 200], [200, 200], ['rectifier'] * 2, ['rectifier'] * 2, 'sigmoid', loss='bern_ces', optimizer=optimizer, batch_size=batch_size)

#m.exprs['loss'] += 0.001 * (m.parameters.enc_in_to_hidden ** 2).sum() / m.exprs['inpt'].shape[0]

climin.initialize.randomize_normal(m.parameters.data, 0, 1e-3)

#climin.initialize.sparsify_columns(m.parameters['enc_in_to_hidden'], 15)
#climin.initialize.sparsify_columns(m.parameters['enc_hidden_to_hidden_0'], 15)
#climin.initialize.sparsify_columns(m.parameters['dec_hidden_to_out'], 15)

f_latent_mean = m.function(['inpt'], 'latent_mean')
f_latent_mean_var = m.function(['inpt'], 'latent_mean')
f_sample = m.function(['sample'], 'dec_output')
f_recons = m.function(['inpt'], 'dec_output')
f_transform = m.function(['inpt'], 'enc_output')
# Out:
# {'dec_in_to_hidden': (200, 200), 'enc_out_bias': 400, 'dec_hidden_to_out': (200, 784), 'enc_hidden_to_hidden_0': (200, 200), 'enc_in_to_hidden': (784, 200), 'enc_hidden_to_out': (200, 400), 'enc_hidden_bias_1': 200, 'enc_hidden_bias_0': 200, 'dec_hidden_bias_1': 200, 'dec_hidden_bias_0': 200, 'dec_out_bias': 784, 'dec_hidden_to_hidden_0': (200, 200)}
# vae.py:42: DeprecationWarning: Division of two integer types with x / y is deprecated, please use x // y for an integer division.
#   n_latent = latent.shape[1] / 2

# %%
max_passes = 250
max_iter = max_passes * X.shape[0] / batch_size
n_report = X.shape[0] / batch_size

stop = climin.stops.AfterNIterations(max_iter)
pause = climin.stops.ModuloNIterations(n_report)

for i, info in enumerate(m.powerfit((X,), (VX,), stop, pause)):
    print i, info['loss'], info['val_loss']
# Out:
# 0 217.802 214.89
# 1
#  198.484 197.01
# 2
#  193.073 191.304
# 3
#  180.73 179.114
# 4
#  169.995 168.578
# 5
#  159.115 157.341
# 6
#  153.246 152.223
# 7
#  150.198 149.294
# 8
#  146.228 144.652
# 9
#  144.534 143.633
# 10
#  140.414 139.365
# 11
#  139.355 138.241
# 12
#  137.481 136.407
# 13
#  135.949 134.894
# 14
#  134.783 134.168
# 15
#  133.521 133.109
# 16
#  132.78 132.371
# 17
#  130.696 130.425
# 18
#  131.98 131.707
# 19
#  128.084 127.66
# 20
#  128.616 128.24
# 21
#  127.519 127.544
# 22
#  126.255 126.288
# 23
#  126.63 126.434
# 24
#  126.684 126.698
# 25
#  124.93 124.759
# 26
#  123.779 123.845
# 27
#  123.184 123.237
# 28
#  123.622 123.667
# 29
#  126.191 126.259
# 30
#  124.113 124.099
# 31
#  124.108 124.104
# 32
#  123.633 123.541
# 33
#  126.115 126.264
# 34
#  123.849 123.957
# 35
#  122.541 122.786
# 36
#  126.799 126.823
# 37
#  121.417 121.598
# 38
#  129.178 129.062
# 39
#  121.686 121.72
# 40
#  121.055 121.436
# 41
#  120.688 121.106
# 42
#  125.28 125.405
# 43
#  122.956 123.237
# 44
#  120.581 120.772
# 45
#  121.257 121.435
# 46
#  120.933 121.215
# 47
#  122.012 122.16
# 48
#  123.436 123.777
# 49
#  122.207 122.596
# 50
#  121.868 122.188
# 51
#  120.385 120.712
# 52
#  121.378 121.772
# 53
#  121.917 122.187
# 54
#  120.977 121.352
# 55
#  122.569 123.058
# /Users/bayerj/devel/climin/climin/util.py:148: UserWarning: Argument named f is not expected by <class 'climin.adadelta.Adadelta'>
#   % (i, klass))

# %%
m.parameters.data[...] = info['best_pars']

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))

S = f_sample(np.random.randn(64, m.n_hiddens_enc[-1]).astype('float32'))
img = tile_raster_images(S, image_dims, (8, 8), (1, 1))
axs[0].imshow(img, cmap=cm.binary)

R = f_recons(X[:64])
img = tile_raster_images(R, image_dims, (8, 8), (1, 1))

axs[1].imshow(img, cmap=cm.binary)

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))
img = tile_raster_images(m.parameters['enc_in_to_hidden'].T, image_dims, (10, 10), (1, 1))
axs[0].imshow(img, cmap=cm.binary)

img = tile_raster_images(m.parameters['dec_hidden_to_out'], image_dims, (10, 10), (1, 1))
axs[1].imshow(img, cmap=cm.binary)

# %%
def show_by_latent(latent0, latent1, latent2, latent3, latent4, latent5, latent6, latent7):
    x = np.array([[latent0, latent1, latent2, latent3, latent4, latent5, latent6, latent7]]).astype('float32')
    out = f_sample(x)
    plt.imshow(out.reshape(image_dims), cmap=cm.binary)

# %%
show_by_latent(1, 2, 3, 4, 5, 6,  7, 8)

# %%
kw = dict(('latent%i' % i, widgets.FloatSliderWidget(min=-4, max=4, step=.01)) for i in range(8))
print kw

i = widgets.interact(show_by_latent, **kw)

# %%
E = f_transform(X)

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.scatter(E[:, 0], E[:, 19], c=Z[:].argmax(1), lw=0, s=10, alpha=.2)

# %% [markdown]
# ### Denoising

# %%
def saltnpepper(X, p=0.1):
    to_pepper = np.random.random(X.shape) < p
    to_salt = np.random.random(X.shape) < p
    X = X.copy()
    X[to_pepper] = 1
    X[to_salt] = 0
    return X

def denoise(m, X):
    H = f_latent_mean(X)
    return f_sample(H)

# %%
noised = saltnpepper(X[:64], 0.05)
denoised = denoise(m, noised)

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))

img = tile_raster_images(noised, image_dims, (8, 8), (1, 1))
axs[0].imshow(img, cmap=cm.binary)

img = tile_raster_images(denoised, image_dims, (8, 8), (1, 1))
axs[1].imshow(img, cmap=cm.binary)

# %%
from breze.arch.component.distributions.mvn import logpdf
import theano.tensor as T
import theano

# %%
sample = T.matrix()
mean = T.vector()
cov = T.matrix()
mvnlogpdf = logpdf(sample, mean, cov)
f_mvnlogpdf = theano.function([sample, mean, cov], mvnlogpdf)

# %%
f_latent_mean_var = m.function(['inpt'], ['latent_mean', 'latent_var'])
f_rec_loss_of_sample = m.function(['sample', 'inpt'], 'rec_loss_sample_wise')

def marginal_ll(m, x, n_samples=10):
    mean, var = f_latent_mean_var(x[np.newaxis])
    
    s = np.random.standard_normal((n_samples, mean.shape[1]))
    #print 'x', s.sum()
    s *= np.sqrt(var)
    s += mean
    s = s.astype('float32')
    
    targets = np.concatenate([x[np.newaxis]] * n_samples)
   
    #print f_rec_loss_of_sample(s, targets)
    
    lp_v_given_s = -f_rec_loss_of_sample(s, targets)
    lq_s_given_v = f_mvnlogpdf(s, mean[0], np.diag(var.flatten()))
    lp_s = f_mvnlogpdf(s, np.zeros(s.shape[1]).astype('float32'), 
                   np.eye(s.shape[1]).astype('float32'))
    
    #print lp_v_given_s
    #print lq_s_given_v
    #print lp_s
    #print '--' * 20
                        
    ll = np.exp(lp_v_given_s + lp_s - lq_s_given_v).mean()
            
    return ll

# %%
ll = 0
for i in range(X.shape[0]):
    ll += np.log(marginal_ll(m, X[i], 2 ** 5))
    
ll /= 50000
print ll
# Out:
# -95.53299161

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-6267e16db359> in <module>()
# ----> 1 marginal_ll(m, X[0], 5)
#
# <ipython-input-104-7f3ff4367c80> in marginal_ll(m, x, n_samples)
#       7
#       8     s = np.random.standard_normal((n_samples, X.shape[1]))
# ----> 9     s *= np.sqrt(var)[np.newaxis]
#      10     s += mean[np.newaxis]
#      11
#
# ValueError: operands could not be broadcast together with shapes (5,784) (1,4) (5,784)
