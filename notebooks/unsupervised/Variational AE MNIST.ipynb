# %%
import cPickle
import gzip

from breze.learn.data import one_hot
from breze.learn.base import cast_array_to_local_type
from breze.learn.utils import tile_raster_images

import climin.stops


import climin.initialize

from breze.learn import sgvb
from matplotlib import pyplot as plt
from matplotlib import cm

import numpy as np

#import fasttsne

from IPython.html import widgets
# %matplotlib inline 

import theano
theano.config.compute_test_value = 'ignore'#'raise'
# Out:
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# C:\Anaconda\lib\site-packages\scipy\lib\_util.py:35: DeprecationWarning: Module scipy.linalg.blas.fblas is deprecated, use scipy.linalg.blas instead
#   DeprecationWarning)
# Using gpu device 0: GeForce GTX 660 Ti

# %%
datafile = '../mnist.pkl.gz'
# Load data.                                                                                                   

with gzip.open(datafile,'rb') as f:                                                                        
    train_set, val_set, test_set = cPickle.load(f)                                                       

X, Z = train_set                                                                                               
VX, VZ = val_set
TX, TZ = test_set

Z = one_hot(Z, 10)
VZ = one_hot(VZ, 10)
TZ = one_hot(TZ, 10)

image_dims = 28, 28

X, Z, VX, VZ, TX, TZ = [cast_array_to_local_type(i) for i in (X, Z, VX,VZ, TX, TZ)]

# %%
fig, ax = plt.subplots(figsize=(9, 9))

img = tile_raster_images(X[:64], image_dims, (8, 8), (1, 1))
ax.imshow(img, cmap=cm.binary)

# %%
batch_size = 200
#optimizer = 'rmsprop', {'step_rate': 1e-4, 'momentum': 0.95, 'decay': .95, 'offset': 1e-6}
optimizer = 'adadelta', {'step_rate': .5, 'momentum': 0.9, 'decay': .95, 'offset': 1e-6}

reload(sgvb)

class MnistAssumptions(sgvb.DiagGaussLatentAssumption, sgvb.BernoulliVisibleAssumption):
    pass

m = sgvb.VariationalAutoEncoder(X.shape[1], [512], 64, [512], ['rectifier'] * 1, ['rectifier'] * 1, 
                                assumptions=MnistAssumptions(),
                                p_dropout_inpt=.1, p_dropout_hiddens=[.1, .1],
                                optimizer=optimizer, batch_size= batch_size)

#m.exprs['loss'] += 0.001 * (m.parameters.enc_in_to_hidden ** 2).sum() / m.exprs['inpt'].shape[0]

climin.initialize.randomize_normal(m.parameters.data, 0, 1e-2)

#climin.initialize.sparsify_columns(m.parameters['enc_in_to_hidden'], 15)
#climin.initialize.sparsify_columns(m.parameters['enc_hidden_to_hidden_0'], 15)
#climin.initialize.sparsify_columns(m.parameters['dec_hidden_to_out'], 15)

#f_latent_mean = m.function(['inpt'], 'latent_mean')
#f_sample = m.function([('gen', 'layer-0-inpt')], 'output')
#f_recons = m.function(['inpt'], 'output')

# %%
m.estimate_nll(X[:10])
# Out:
# DEBUG: nvcc STDOUT c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpqnoxab/7580ccc3b67ce25d3ccdef831c80b13a.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpqnoxab/7580ccc3b67ce25d3ccdef831c80b13a.exp
#
# DEBUG: nvcc STDOUT
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmp2pobgj/561989422ceb6343cb264e26912ebd28.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmp2pobgj/561989422ceb6343cb264e26912ebd28.exp
#
# DEBUG: nvcc STDOUT
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpnltwuq/9cba0fb13792f2e937d39773f3775b0f.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpnltwuq/9cba0fb13792f2e937d39773f3775b0f.exp
# 816.55671370240384

# %%
max_passes = 250
max_iter = max_passes * X.shape[0] / batch_size
n_report = X.shape[0] / batch_size

stop = climin.stops.AfterNIterations(max_iter)
pause = climin.stops.ModuloNIterations(n_report)

for i, info in enumerate(m.powerfit((X,), (VX,), stop, pause)):
    print i, info['loss'], info['val_loss']
# Out:
# DEBUG: nvcc STDOUT c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmp8xviv5/76c81bcef16d70ccd66841f0a270de95.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmp8xviv5/76c81bcef16d70ccd66841f0a270de95.exp
#
# DEBUG: nvcc STDOUT
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpgherxa/2755b833fc389172fc569731952361a4.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpgherxa/2755b833fc389172fc569731952361a4.exp
#
# DEBUG: nvcc STDOUT
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpu3m4kz/0f5a93b625132298e2b97b2cf2b0dedc.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpu3m4kz/0f5a93b625132298e2b97b2cf2b0dedc.exp
#
# DEBUG: nvcc STDOUT
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpbcrubb/d3e61a5a9247ac4d29531e0e58770094.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpbcrubb/d3e61a5a9247ac4d29531e0e58770094.exp
#
# DEBUG: nvcc STDOUT
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpgujo7x/a7630353082a5d0f0d1d2017abaab0a1.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpgujo7x/a7630353082a5d0f0d1d2017abaab0a1.exp
#
# DEBUG: nvcc STDOUT
# 0 194.398 192.502
# 1
#  163.79 162.534
# 2
#  150.17 149.359
# 3
#  139.311 138.413
# 4
#  131.541 130.994
# 5
#  126.447 125.993
# 6
#  122.613 122.535
# 7
#  118.801 118.526
# 8
#  115.995 115.813
# 9
#  114.375 114.323
# 10
#  112.708 112.698
# 11
#  111.979 112.043
# 12
#  110.652 110.704
# 13
#  109.75 109.853
# 14
#  109.208 109.278
# 15
#  108.48 108.752
# 16
#  108.506 108.733
# 17
#  107.809 108.104
# 18
#  107.501 107.876
# 19
#  107.343 107.711
# 20
#  106.503 106.865
# 21
#  106.279 106.705
# 22
#  105.866 106.354
# 23
#  105.699 105.995
# 24
#  105.375 105.84
# 25
#  105.315 105.693
# 26
#  105.106 105.434
# 27
#  104.835 105.359
# 28
#  104.807 105.218
# 29
#  104.664 105.212
# 30
#  104.596 105.102
# 31
#  104.492 104.99
# 32
#  104.162 104.805
# 33
#  104.084 104.595
# 34
#  104.128 104.655
# 35
#  104.009 104.537
# 36
#  103.659 104.262
# 37
#  103.671 104.185
#  c:\anaconda\lib\site-packages\numpy\core\include\numpy\npy_1_7_deprecated_api.h(12) : Warning Msg: Using deprecated NumPy API, disable it by #defining NPY_NO_DEPRECATED_API NPY_1_7_API_VERSION
#    Creating library C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpx_pcpu/e400f833c90f89bcb388e35754f06630.lib and object C:/Users/karlma/AppData/Local/Theano/compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_58_Stepping_9_GenuineIntel-2.7.7-64/tmpx_pcpu/e400f833c90f89bcb388e35754f06630.exp

# %%
m.parameters.data[...] = info['best_pars']

# %%
f_sample = m.function([m.sample], 'output')
f_recons = m.function(['inpt'], 'output')

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))

S = f_sample(np.random.randn(64, m.n_latent).astype('float32'))[:, :784]
img = tile_raster_images(S, image_dims, (8, 8), (1, 1))
axs[0].imshow(img, cmap=cm.binary)

R = f_recons(X[:64])[:, :784]
img = tile_raster_images(R, image_dims, (8, 8), (1, 1))

axs[1].imshow(img, cmap=cm.binary)

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))
img = tile_raster_images(m.parameters[m.vae.recog.layers[0].weights].T, image_dims, (10, 10), (1, 1))
axs[0].imshow(img, cmap=cm.binary)

img = tile_raster_images(m.parameters[m.vae.gen.layers[-1].weights], image_dims, (10, 10), (1, 1))
axs[1].imshow(img, cmap=cm.binary)

# %%
f_L = m.function(['inpt'], 'latent')

# %%
L = f_L(X)

# %%
fig, ax = plt.subplots(figsize=(9, 9))
ax.scatter(L[:, 10], L[:, 2], c=Z[:].argmax(1), lw=0, s=10, alpha=.2)

# %%
m.estimate_nll(TX) / TX.shape
# Out:
# 1095741.93376681

# %%
1095741.93376681/10000
# Out:
# 109.574193376681

# %% [markdown]
# ### Denoising

# %%
def saltnpepper(X, p=0.1):
    to_pepper = np.random.random(X.shape) < p
    to_salt = np.random.random(X.shape) < p
    X = X.copy()
    X[to_pepper] = 1
    X[to_salt] = 0
    return X

# %%
noised = saltnpepper(X[:64], 0.05)
denoised = m.denoise(noised)

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 9))

img = tile_raster_images(noised, image_dims, (8, 8), (1, 1))
axs[0].imshow(img, cmap=cm.binary)

img = tile_raster_images(denoised, image_dims, (8, 8), (1, 1))
axs[1].imshow(img, cmap=cm.binary)

# %%
print m.estimate_nll(X[:10]).mean()
