# %%
import cPickle
import gzip

from PIL import Image
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import theano.tensor as T
import theano

import climin.stops
import climin.initialize

from IPython.core import pylabtools
pylabtools.figsize(16, 9)
from IPython.core.display import Image as image

from breze.learn import autoencoder
#from breze.learn.rica import Rica
from breze.learn.utils import tile_raster_images

# %% [markdown]
# Helper functions
# ================

# %%
def scale_cols_to_unit_interval(arr):
    arr = arr.copy()
    arr -= arr.min(axis=0)
    arr /= arr.max(axis=0)
    arr *= 255
    return arr.astype('uint8')

# %% [markdown]
# Prepare Data
# ============
#
# We load the MNIST data. It is available at http://www.iro.umontreal.ca/~lisa/deep/data/mnist/mnist.pkl.gz.
#
# The inputs all lie between 0 and 1. Each target is a one of k variable.

# %%
datafile = 'mnist.pkl.gz'
# Load data.                                                                                                   

with gzip.open(datafile,'rb') as f:                                                                        
    train_set, val_set, test_set = cPickle.load(f)                                                       

X, Z = train_set                                                                                               
VX, VZ = val_set
TX, TZ = test_set

image_dims = 28, 28

# %% [markdown]
# Configuration
# =============

# %%
method = 'contractive'     # One of: basic, sparse, contractive, rica, denoising

n_features = 32
max_passes = 100

feature_dims = int(math.ceil(np.sqrt(n_features))), int(math.ceil(np.sqrt(n_features)))

batch_size = 250
hidden_transfer = 'sigmoid'
out_transfer = 'sigmoid'
loss = 'squared'
#optimizer = 'adadelta', {'steprate': 0.001, 'momentum': 0.9, 'decay': 0.9}
optimizer = 'rmsprop', {'step_rate': 0.001, 'momentum': 0.9, 'decay': 0.9}
#optimizer = 'gd', {'steprate': 0.01, 'momentum': 0.95, 'momentum_type': 'nesterov'}
#optimizer = 'lbfgs'
sparsify = False
par_std = 1e-1
tied_weights = False

# %% [markdown]
# Setup
# =====

# %%
losses = []

if method == 'basic':
    fe = autoencoder.AutoEncoder(int(X.shape[1]), [n_features], 
                     hidden_transfers=[hidden_transfer], out_transfer=out_transfer,
                     loss_ident=loss, 
                     batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)
elif method == 'sparse':
    sparsity_loss = 'bern_bern_kl'
        
    sparsity_target = 0.01
    c_sparsity = 2.5
    #batch_size = 50000

    fe = autoencoder.SparseAutoEncoder(X.shape[1], [n_features], 
                           hidden_transfers=[hidden_transfer], out_transfer=out_transfer,
                           loss=loss, 
                           sparsity_loss=sparsity_loss,
                           c_sparsity=c_sparsity,
                           sparsity_target=sparsity_target,
                           batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)
elif method == 'denoising':
    c_noise = .2
    noise_type = 'mask'
    batch_size = 250

    fe = autoencoder.DenoisingAutoEncoder(X.shape[1], [n_features],
                              hidden_transfers=[hidden_transfer], out_transfer=out_transfer,
                              loss=loss, 
                              c_noise=c_noise, noise_type=noise_type,
                              batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)    

elif method == 'contractive':
    c_jacobian = 1.5
    batch_size = 250

    fe = autoencoder.ContractiveAutoEncoder(X.shape[1], [n_features], 
                                hidden_transfers=[hidden_transfer], out_transfer=out_transfer,
                                loss=loss, 
                                c_jacobian=c_jacobian,
                                batch_size=batch_size, optimizer=optimizer, tied_weights=tied_weights)    
elif method == 'rica':
    c_ica = 0.1
    rica_hidden_transfer = 'identity'
    feature_transfer = 'softabs'
    
    fe = Rica(X.shape[1], n_features, c_ica=c_ica, 
              hidden_transfer=rica_hidden_transfer, feature_transfer=feature_transfer, out_transfer=out_transfer,
              loss=loss, optimizer=optimizer)

# %%
climin.initialize.randomize_normal(fe.parameters.data)

if sparsify:
    climin.initialize.sparsify_columns(fe.parameters['in_to_hidden'], sparsify)

# %% [markdown]
# Training
# ========

# %%
batches_per_pass = float(X.shape[0]) / batch_size
max_iter = int(math.ceil(max_passes * batches_per_pass))

print "max_iter", max_iter

stop = climin.stops.AfterNIterations(max_iter)
pause = climin.stops.ModuloNIterations(batches_per_pass)

# Set up a nice printout.
keys = '#', 'loss', 'val loss'#, 'step_length'
max_len = max(len(i) for i in keys)
header = '   '.join(i.ljust(max_len) for i in keys)
print header
print '-' * len(header)


for i, info in enumerate(fe.powerfit((X,), (VX,), stop, pause)):
    losses.append((info['loss'], info['val_loss']))
    
    row = '%i' % i, '%.6f' % info['loss'], '%.6f' % info['val_loss'],# '%.6f' % info['step_length']
    print '   '.join(i.ljust(max_len) for i in row)
# Out:
# max_iter 50000
# #          loss       val loss
# ------------------------------
# 0          53.091270   52.432034
# 1          39.829274   39.427769
# 2          31.045644   30.721515
# 3          27.057356   26.849351
# 4          24.602079   24.497385
# 5          22.392324   22.351956
# 6          20.868009   20.854567
# 7          19.532855   19.537603
# 8          18.171530   18.164311
# 9          17.280253   17.252545
# 10         16.573389   16.525666
# 11         15.994412   15.921254
# 12         15.522077   15.454920
# 13         15.131889   15.071691
# 14         14.803089   14.733765
# 15         14.534678   14.473131
# 16         14.163937   14.111905
# 17         13.792602   13.739007
# 18         13.547947   13.487111
# 19         13.378169   13.331785
# 20         13.203529   13.150833
# 21         12.940971   12.883378
# 22         12.715257   12.668883
# 23         12.516074   12.481530
# 24         12.328243   12.289572
# 25         12.152709   12.125709
# 26         11.976293   11.954565
# 27         11.828204   11.800625
# 28         11.580713   11.562949
# 29         11.332014   11.329296
# 30         11.106705   11.108158
# 31         10.888082   10.881474
# 32         10.715806   10.718694
# 33         10.587645   10.582885
# 34         10.453878   10.456189
# 35         10.398411   10.400175
# 36         10.291670   10.292739
# 37         10.231304   10.242082
# 38         10.173270   10.176026
# 39         10.161916   10.185504
# 40         10.075163   10.102957
# 41         10.042667   10.066634
# 42         10.040028   10.066252
# 43         9.980295   10.000462
# 44         9.902946   9.926490
# 45         9.873435   9.895344
# 46         9.837053   9.853211
# 47         9.781794   9.807554
# 48         9.740877   9.775764
# 49         9.733734   9.775885
# 50         9.607403   9.649963
# 51         9.549756   9.598760
# 52         9.557280   9.597650
# 53         9.393992   9.436900
# 54         9.390160   9.440896
# 55         9.269132   9.318454
# 56         9.248984   9.314365
# 57         9.279079   9.352278
# 58         9.114204   9.171534
# 59         9.076026   9.139712
# 60         9.036738   9.099569
# 61         8.978630   9.045914
# 62         8.899387   8.964506
# 63         8.853066   8.919733
# 64         8.998259   9.065862
# 65         8.828983   8.897666
# 66         8.757050   8.826288
# 67         8.772047   8.834020
# 68         8.810340   8.894175
# 69         8.779576   8.837839
# 70         8.744286   8.795622
# 71         8.731247   8.796482
# 72         8.734069   8.803154
# 73         8.715902   8.779453
# 74         8.690632   8.764517
# 75         8.697040   8.781434
# 76         8.688735   8.769558
# 192        8.243323   8.356514
# 193        8.266136   8.359682
# 194        8.331261   8.440148
# 195        8.272104   8.389321
# 196        8.234193   8.345856
# 197        8.291498   8.410625
# 198        8.258210   8.359126
# 199        8.232724   8.351871
# 200        8.248329   8.360595
# 201        8.235052   8.349012
# 202        8.227316   8.339909
# 203        8.218034   8.315157
# 204        8.233067   8.337011
# 205        8.249677   8.356541
# 206        8.193725   8.296697
# 207        8.273458   8.388156
# 208        8.248346   8.351561
# 209        8.232019   8.329578
# 210        8.235669   8.352109
# 211        8.184718   8.301743
# 212        8.224309   8.327152
# 213        8.190213   8.295295
# 214        8.242538   8.349262
# 215        8.229710   8.346385
# 216        8.195656   8.303368
# 217        8.196842   8.312150
# 218        8.207110   8.306814
# 219        8.160944   8.265106
# 220        8.200706   8.314738
# 221        8.191100   8.293250
# 222        8.213875   8.316983
# 223        8.192790   8.284108
# 224        8.240581   8.365612
# 225        8.284343   8.399134
# 226        8.167110   8.287733
# 227        8.171407   8.270491
# 228        8.192684   8.297027
# 229        8.161532   8.275688
# 230        8.225344   8.315357
# 231        8.192481   8.296858
# 232        8.175152   8.282502
# 233        8.169888   8.280416
# 234        8.192745   8.286946
# 235        8.144335   8.252222
# 236        8.164680   8.274076
# 237        8.151244   8.264777
# 238        8.197315   8.306270
# 239        8.155048   8.260024
# 240        8.187052   8.299725
# 241        8.181567   8.280954
# 242        8.246874   8.370157
# 243        8.144059   8.246168
# 244        8.171229   8.276629
# 245        8.146955   8.253051
# 246        8.146159   8.264994
# 247        8.121043   8.236862
# 248        8.165731   8.268996
# 249        8.131685   8.239779

# %% [markdown]
# Reconstruction and Errors
# =========================

# %%
fig = plt.figure(figsize=((15, 5)))

img = tile_raster_images(TX[:64], image_dims, (8, 8), (1, 1))
ax0 = fig.add_subplot(131)
ax0.imshow(img, cmap=cm.binary)

f_reconstruct = fe.function(['inpt'], 'output')
TR = f_reconstruct(TX[:64])
img = tile_raster_images(TR, image_dims, (8, 8), (1, 1))
ax1 = fig.add_subplot(132)
ax1.imshow(img, cmap=cm.binary)

img = tile_raster_images(TR - TX[:64], image_dims, (8, 8), (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
ax2 = fig.add_subplot(133)
ax2.imshow(img, cmap=cm.binary)

# %% [markdown]
# Visualize Filters
# =================

# %%
filters = fe.filters_in_to_hidden.T  
filters_out = fe.filters_hidden_to_out
filters_resh = np.reshape(filters, [filters.shape[0], image_dims[0], image_dims[1]])
filters_crop = filters_resh[:, 4:image_dims[0] - 4, 4:image_dims[1] - 4]
filters_cropped = np.reshape(filters_crop, [filters.shape[0], (image_dims[0]-8) * (image_dims[1]-8)])
print filters_cropped.shape
print filters.shape
print filters_out.shape
# Out:
# (32L, 400L)
# (32L, 784L)
# (32L, 784L)

# %%
tile_size = int(math.ceil(np.sqrt(n_features))), int(math.ceil(np.sqrt(n_features)))

img = tile_raster_images(filters, image_dims, tile_size, (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
plt.imshow(img, cmap=cm.binary)

# %%
img = tile_raster_images(filters_cropped, (20,20), tile_size, (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
plt.imshow(img, cmap=cm.binary)

# %%
img = tile_raster_images(filters_out, image_dims, tile_size, (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
plt.imshow(img, cmap=cm.binary)
