# %%
import cPickle
import gzip
import time

from PIL import Image
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import theano.tensor as T

import climin.stops
import climin.initialize
import climin.schedule

from IPython.core import pylabtools
pylabtools.figsize(16, 9)
from IPython.core.display import Image as image

from breze.learn.mlp import Mlp
from breze.learn.utils import tile_raster_images
import breze.learn.base

# %% [markdown]
# Prepare data

# %%
datafile = 'mnist.pkl.gz'
# Load data.                                                                                                   

with gzip.open(datafile,'rb') as f:                                                                        
    train_set, val_set, test_set = cPickle.load(f)                                                       

X, Z = train_set                                                                                               
VX, VZ = val_set
TX, TZ = test_set

image_dims = 28, 28

X, Z, VX, VZ, TX, TZ = [breze.learn.base.cast_array_to_local_type(i) for i in (X, Z, VX, VZ, TX, TZ)]

# %% [markdown]
# Configuration

# %%
n_hiddens = [1000, 500, 250, 2, 250, 500, 1000]
hidden_transfers = ['sigmoid'] * 3 + ['identity'] + ['sigmoid'] * 3
out_transfer = 'sigmoid'
batch_size = 200
max_passes = 100
optimizer = 'gd', {'steprate': 0.0005, 'momentum': climin.schedule.sutskever_blend(.995, 250), 'momentum_type': 'nesterov'}
loss = 'nces'
sparsify = 15
par_std = 1.0
max_iter = max_passes * X.shape[0] / batch_size
batches_per_pass = int(math.ceil(float(X.shape[0]) / batch_size))

# %% [markdown]
# Setup model

# %%
mlp = Mlp(
    X.shape[1], n_hiddens, X.shape[1], hidden_transfers=hidden_transfers, out_transfer=out_transfer, loss=loss,
    optimizer=optimizer, batch_size=batch_size)
mlp.parameters.data[:] = np.random.normal(0, par_std, mlp.parameters.data.shape)
climin.initialize.sparsify_columns(mlp.parameters['in_to_hidden'], 15)
for i in range(6):
    if i in (2, 3):
        continue
    climin.initialize.sparsify_columns(mlp.parameters['hidden_to_hidden_%i' % i], 15)

# %%
pause = climin.stops.modulo_n_iterations(batches_per_pass)
stop = climin.stops.after_n_iterations(max_iter)

start = time.time()

print '#\ttime\tloss\tval loss'
for info in mlp.powerfit((X, X), (VX, VX), stop, pause):
    info['time_passed'] = time.time() - start
    print '%(n_iter)i\t%(time_passed).2f\t%(loss)g\t%(val_loss)g' % info
# Out:
# #	time	loss	val loss
# 0	21.56	4946.79	4947.9
# 250	46.19	222.076	220.169
# 500	70.56	207.13	205.731
# 750	95.37	196.149	194.792
# 1000	120.23	192.639	190.984
# 1250	144.99	189.707	188.356
# 1500	169.45	184.664	183.044
# 1750	193.70	178.595	176.631
# 2000	217.75	175.328	173.63
# 2250	241.72	171.897	169.954
# 2500	265.60	169.101	167.271
# 2750	289.47	167.27	165.822
# 3000	313.28	165.26	163.638
# 3250	337.11	164.016	162.503
# 3500	360.88	162.114	160.61
# 3750	384.62	160.817	159.723
# 4000	408.35	159.262	158.013
# 4250	432.05	158.274	157.145
# 4500	456.14	157.183	156.105
# 4750	479.85	155.743	154.546
# 5000	503.59	154.296	153.215
# 5250	527.27	152.958	151.621
# 5500	550.99	152.06	150.653
# 5750	574.74	150.709	149.353
# 6000	598.43	150.319	148.768
# 6250	622.15	149.451	147.896
# 6500	645.88	149.017	147.654
# 6750	669.59	147.147	145.704
# 7000	693.30	146.456	144.991
# 7250	717.01	145.553	144.444
# 7500	740.74	144.807	143.677
# 7750	764.46	144.049	142.84
# 8000	788.26	143.594	142.288
# 8250	811.94	143.372	142.163
# 8500	835.63	142.426	141.179
# 8750	859.26	141.54	140.622
# 9000	883.17	141.362	140.727
# 9250	906.85	141.009	140.244
# 9500	930.55	140.911	140.226
# 9750	954.24	140.295	139.901
# 10000	977.96	139.422	138.773
# 10250	1001.69	139.383	138.919
# 10500	1025.37	138.787	138.421
# 10750	1049.01	138.903	138.287
# 11000	1072.67	138.453	138.079
# 11250	1096.30	137.635	137.403
# 11500	1119.95	137.861	137.778
# 11750	1143.58	137.348	137.353
# 12000	1167.25	136.798	136.748
# 12250	1190.90	136.88	136.487
# 12500	1214.56	136.662	136.352
# 12750	1238.24	136.175	136.051
# 13000	1261.85	136.262	135.893
# 13250	1285.50	136.996	136.376
# 13500	1309.18	135.311	135.202
# 13750	1332.82	135.123	135.033
# 14000	1356.46	135.074	134.974
# 14250	1380.12	134.837	134.606
# 14500	1403.80	134.627	134.525
# 14750	1427.43	134.804	134.634
# 15000	1451.00	134.709	134.921
# 15250	1474.71	134.167	134.178
# 15500	1498.40	134.406	134.553
# 15750	1522.02	133.917	133.859
# 16000	1545.69	133.827	134.051
# 16250	1569.29	133.66	133.813
# 16500	1592.94	133.844	133.92
# 16750	1616.55	133.821	133.689
# 17000	1640.16	133.095	133.053
# 17250	1663.87	133.374	133.48
# 17500	1687.51	133.076	132.976
# 17750	1711.16	133.253	133.253
# 18000	1734.80	133.186	133.716
# 18250	1758.47	132.625	132.826
# 18500	1782.11	133.119	133.08
# 18750	1805.75	133.224	133.357
# 19000	1829.41	132.513	132.451
# 19250	1853.11	132.271	132.607
# 19500	1876.69	134.407	134.276
# 19750	1900.46	132.645	132.631
# 20000	1924.23	133.314	132.865
# 20250	1947.97	132.553	132.826
# 20500	1971.85	132.379	132.472
# 20750	1995.47	131.978	132.44
# 21000	2019.13	132.752	133.444
# 21250	2042.81	132.855	132.783
# 21500	2066.47	132.412	132.545
# 21750	2090.22	132.636	132.592
# 22000	2113.94	132.385	132.385
# 22250	2137.72	132.99	132.723
# 22500	2161.45	133.369	133.36
# 22750	2185.17	134.352	134.266
# 23000	2209.01	133.38	133.175
# 23250	2233.01	133.361	133.018
# 23500	2257.11	133.036	132.536
# 23750	2280.93	132.831	132.35
# 24000	2304.75	132.702	132.6
# 24250	2328.50	133.158	132.479
# 24500	2352.29	132.915	132.529
# 24750	2376.14	134.086	133.949
# /Users/bayerj/devel/climin/climin/util.py:111: UserWarning: Argument named f is not expected by <class 'climin.gd.GradientDescent'>
#   % (i, klass))

# %% [markdown]
# Visualize
# =========

# %% [markdown]
# ### Embeddings

# %%
f_encode = mlp.function(['inpt'], 'hidden_3')

# %%
TE = f_encode(TX)
scatter(TE[:, 0], TE[:, 1], c=TZ, marker='x', alpha=.3)

# %% [markdown]
# ### Reconstructions

# %%
fig = plt.figure(figsize=((15, 5)))

img = tile_raster_images(TX[:64], image_dims, (8, 8), (1, 1))
ax0 = fig.add_subplot(131)
ax0.imshow(img, cmap=cm.binary)

f_reconstruct = mlp.function(['inpt'], 'output')
TR = f_reconstruct(TX[:64])
img = tile_raster_images(TR, image_dims, (8, 8), (1, 1))
ax1 = fig.add_subplot(132)
ax1.imshow(img, cmap=cm.binary)

img = tile_raster_images(TR - TX[:64], image_dims, (8, 8), (1, 1))
# We write the filters to a file, since I do not like the matplot imshow functionality. :)
ax2 = fig.add_subplot(133)
ax2.imshow(img, cmap=cm.binary)
