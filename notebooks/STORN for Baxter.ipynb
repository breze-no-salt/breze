# %% [markdown]
# Stochastic Recurrent Networks for human movement modelling
# ===============================================================================
#
# This notebook presents how to use stochastic recurrent networks (STORNs) for
# modelling human movement. The method has been proposed in
#
#  * Bayer, Justin, and Christian Osendorfer. "Learning Stochastic Recurrent Networks." arXiv preprint arXiv:1411.7610 (2014). [Link](arxiv.org/abs/1411.7610).
#
# It is best to revisit the paper to get a theoretical understanding of the method,
# but a quick recap follows.
#
# The model
# ---
#
# We are interested in modelling sequences $\{x_{1:T}\}_{i=1}^N$ over a vectorial
# space. To do so, we assume that the data is generated by the following model:
#
# $$h_t = f(h_{t-1}W + x_t V + z_t \hat{V} + b), \\
# x_{t+1} = g(h_t Q + \hat{b}).$$
#
# Here, $z_t \sim \mathcal{N}(0, 1)$ are **stochastic units** which help to model
# the data.
#
# As can be seen, the model is a generalisation of plain RNNs: if we set
# $\hat{V} = \mathbf{0}$, we will recover an Elman network.
# However, adding stochastic units can greatly enhance the predictive capabilities
# of our model.
#
# For one, it lets us model dependencies between the components of each $x_t$.
# Further, it can express more complicated distributions. For example, the output
# of an RNN is just a point. If we do not attach any probabilistic meanings to
# those points, they will form a Dirac distribution. However, if we integrate all
# the $z_t$ out, we can get any (yes, any) distribution--Gaussian, Laplace,
# student's T or even mixtures.
#
#
# The learning algorithm/estimator
# ---
#
# We are using a certain flavor of variational inference, namely *stochastic gradient variational Bayes* (SGVB)
# to find good paramters--that is $\{h_0, V, \hat{V}, Q, b \hat{b}\}$--for our model.
# SGVB has been described in
#
#  * Kingma, Diederik P., and Max Welling. "Auto-encoding variational bayes." arXiv preprint arXiv:1312.6114 (2013) and
#  * Rezende, Danilo Jimenez, Shakir Mohamed, and Daan Wierstra. "Stochastic backpropagation and approximate inference in deep generative models." arXiv preprint arXiv:1401.4082 (2014).
#
# but the STORN article features a quick recap. We will do a shorter one.
#
# The main idea is to minimize an upper bound on the negative log-likelihood,
# which also makes a variational approximation $q(z|x)$ close to the true posterior
# $p(z|x)$. This is done by making $q$ a parameterised model conditioned on the
# input (which is weird in the first moment); in the original papers, a neural net
# was used for that. Here, we are using (bidirectional) recurrent networks. The
# parameters of that model (the recognition model or inference model) are optimised
# jointly with the generative model above.
#
# Doing so, we get something for free: $q$ can be used for all kinds of approximate
# inference. We can perform an approximate denoising by looking at an observation $x$,
# obtaining the maximum of the approximate posterior $\text{arg max}_{\hat{z}} q(\hat{z}|x)$
# and then reconstruct $\hat{x}$ from that.
#
# We can also do impute missing values by doing so many times (using sampling from $q$
# instead of MAP) and re-feed each $\hat{x}$ into our model. This is equivalent to MCMC
# sampling from the model. If we clamp some components of $x$, we will do proper missing
# value imputation.
#
# Furthermore, there exists an efficient estimator for the NLL that does not rely on
# a costly Markov chain--something which is not available for the RBM family.
#
#
# Outline
# ---
#
# To proceed with the notebook, you will need the saltier-storn branch of Breze, which can be found here:
#
#   * https://github.com/breze-no-salt/breze/tree/saltier-storn
#
# You can install breze with the usual
#
#   ``pip install --user -e .``
#
# You will also need
# [Theano](http://deeplearning.net/software/theano/) and
# [climin](climin.readthedocs.org).

# %%
# Quite a few imports.

import cPickle
import gzip
import itertools
import math
import time

import numpy as np
import gnumpy as gp
import theano
import theano.tensor as T

from breze.learn.data import interleave, padzeros, split
from breze.learn import base
from breze.learn import sgvb
import breze.learn.display as D
from breze.learn.data import interleave, padzeros, split

from breze.arch.component.varprop import transfer
from breze.arch.util import WarnNaNMode

from breze.learn.trainer.trainer import Trainer
from breze.learn.trainer.report import OneLinePrinter


import climin.initialize
import climin.stops
import climin.mathadapt as ma

import matplotlib.pyplot as plt
from matplotlib import cm

# %matplotlib inline

#theano.config.compute_test_value = 'raise'

from scipy.io import loadmat
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# gnumpy: failed to use gpu_lock. Using board #0 without knowing whether it is in use or not.
# Using gpu device 0: Quadro K600

# %% [markdown]
# Data format
# -------------------------------------------------------------------------------
#
# A word on the data format. To make things efficient, we need to put all the
# sequential data in 3D arrays. This is done by padding the shorter sequences
# with zeros. To make sure that those zeros don't interfer with learning, we will
# also use masks (that is binary matrices) with which the component wise loss
# is multiplied--that way, only the real data points will contribute to it.
#
# It will also mean longer processing times as if all sequences were of the same
# length. But it is way faster than working through each one separately.
#
# An array is thus of the form
#
#   ``(T, N, D)``
#
# where ``T`` is the number of time steps, ``N`` is the number of samples and
# ``D`` is the dimensionality of the data.
#
# The training and validation data will also be chunked into smaller sequences,
# e.g. ``100``. This is not done for the testing data. I personally do not
# believe that it affects performance much.
#
# Naming convention for data
# ---
#
# Throughout Breze, ``X`` is the training data, ``VX`` is the validation data
# and ``TX`` is the testing data. ``M``, ``VM`` and ``TM`` are the corresponding
# masks.
#
# Often, we will not chunk the testing data. In that case, the testing data is
# contained in a list called ``txs``, which contains many sequences of differing
# length of the shape ``(T, D)``. In this case, we only have a single testing
# sequence, which is why it is called ``tx``.

# %%
import h5py
def load_data():
    datafile = 'P:/Datasets/BaxterCollision/data/bluebear/bluebear.h5'
    with h5py.File(datafile) as fp:
        dev_seqs = [np.array(fp['dev'][i]) for  i in fp['dev']]
        txs = [np.array(fp['test'][i]) for  i in fp['test']]
        tzs = np.array(fp['test_anomaly_label'])

    x = dev_seqs[:80]
    m = np.concatenate(x).mean(axis=0)
    s = np.concatenate(x).std(axis=0)

    x = [(xx-m)/s for xx in x]
    vx = [(vxx-m)/s for vxx in dev_seqs[80:]]
    txs = [(tx-m)/s for tx in txs]

    X, M = tuple(interleave(l) for l in padzeros(x, front=False, return_mask=True))
    VX, VM = tuple(interleave(l) for l in padzeros(vx, front=False, return_mask=True))
    TX, TM = tuple(interleave(l) for l in padzeros(txs, front=False, return_mask=True))
    M, VM, TM = M[:,:,:1], VM[:,:,:1], TM[:,:,:1]
    
    X, M, VX, VM, TX, TM = [base.cast_array_to_local_type(i) for i in (X, M, VX, VM, TX, TM)]
    txs = [base.cast_array_to_local_type(i) for i in txs]

    return {
        'train': (X,M),
        'val': (VX,VM),
        'test': (TX,TM)
    }



data = load_data()
X, M = data['train']
VX, VM = data['val']
TX, TM = data['test']

#print 'Masking ratios: train %g val %g' %(M.mean(), VM.mean())
#print '(That is the fraction of elements in the data arrays which do not stem from padding.)'
# Out:
# z:\anomalydetection\breze\breze\learn\base.py:39: UserWarning: Implicilty converting numpy.ndarray to gnumpy.garray
#   warnings.warn('Implicilty converting numpy.ndarray to gnumpy.garray')

# %% [markdown]
# Model initialisation
# --------------------------------------------------------------------------------
#
# Here we initialise the model. We will comment the most important parameters in the
# cell. The hyper parameters were obtained using Bayesian optimisation via whetlab.

# %%
pars = {
 'batch_size': 20,
 'latent_assumption': 'DiagGauss',
 'minutes': 600,
 'n_gen_hidden_units': 64,
 'n_gen_layers': 3,
 'n_latents': 3,
 'n_rec_hidden_units': 64,
 'n_recog_layers': 2,
 'optimizer': 'adadelta',
 'out_std': 0.01,
 'p_dropout_hidden_to_out': 0.9,
 'p_dropout_hiddens': 0.3,
 'p_dropout_inpt': 0.8,
 'p_dropout_shortcut': 0.8,
 'par_init_std': 1,
 'par_init_std_in': 1e-06,
 'transfer_gen': 'tanh',
 'transfer_rec': 'sigmoid'
}

if pars['latent_assumption'] == 'KW':
    myrecog = sgvb.KWLatentBiStornMixin
else:
    myrecog = sgvb.GaussLatentBiStornMixin

if pars['optimizer'] == 'adadelta':
    optimizer = 'adadelta', {'step_rate': 1,
                             'momentum': 0.99,
                             'decay': 0.78,
                             'offset': 0.00005}
else:
    optimizer = pars['optimizer']


MyStorn = type('MyStorn', (sgvb.StochasticRnn, myrecog, sgvb.ConstVarGaussVisibleStornMixin), {})
MyStorn.shared_std = True
MyStorn.fixed_std = theano.shared(np.ones((1,)) * np.array(pars['out_std']).astype(theano.config.floatX),
                              broadcastable=(True,))

#class MyStorn(sgvb.StochasticRnn,
#              myrecog,
#              sgvb.ConstVarGaussVisibleStornMixin):
#    shared_std = True
#    fixed_std = theano.shared(np.ones((1,)) * np.array(pars['out_std']).astype(theano.config.floatX),
#                              broadcastable=(True,))

m = MyStorn(
    n_inpt=int(data['test'][0].shape[2]),
    n_hiddens_recog=[pars['n_rec_hidden_units']] * pars['n_recog_layers'],
    n_latent=pars['n_latents'],
    n_hiddens_gen=[pars['n_gen_hidden_units']] * pars['n_gen_layers'],
    recog_transfers=[pars['transfer_rec']] * pars['n_recog_layers'],
    gen_transfers=[pars['transfer_gen']] * pars['n_gen_layers'],
    use_imp_weight=True,
    #assumptions=Assumptions(),
    batch_size=pars['batch_size'],
    optimizer=optimizer,
    p_dropout_inpt=pars['p_dropout_inpt'],
    p_dropout_hiddens=pars['p_dropout_hiddens'],
    p_dropout_hidden_to_out=pars['p_dropout_hidden_to_out'],
    p_dropout_shortcut=pars['p_dropout_shortcut']
)

m.initialize(
    par_std=pars['par_init_std'],
    par_std_in=pars['par_init_std_in'],
    #sparsify_affine=sparsify_in,
    #sparsify_rec=sparsify_rec,
    spectral_radius=None)

m.optimizer = 'rmsprop', {'step_rate': 1e-4, 
                        'momentum': 0.9, 
                        'decay': 0.78, 
                        'offset': 0.00005, 
                        'step_adapt': False, 'step_rate_min': 1e-8, 'step_rate_max': 1}

#m.parameters[m.vae.gen.std][...] = 0.01

#########
# BUILDING AND INITIALIZING TRAINER
#########
n_report = 50
t = Trainer(
    model=m,
    data=data,
    stop=climin.stops.Any([
                            climin.stops.TimeElapsed(pars['minutes'] * 60),
                            ]),
    pause=climin.stops.ModuloNIterations(n_report),
    report=OneLinePrinter(['n_iter', 'train_loss', 'val_loss', 'test_loss']),
    interrupt=climin.stops.OnSignal(),
    loss_keys=['train', 'val', 'test'])

# %%
m.optimizer = 'rmsprop', {'step_rate': 1e-2, 
                        'momentum': 0.9, 
                        'decay': 0.78, 
                        'offset': 0.00005, 
                        'step_adapt': False, 'step_rate_min': 1e-8, 'step_rate_max': 1}

# %%
#m.parameters[m.vae.gen.std][...] = 0.01

# %% [markdown]
# Training
# ===

# %%
infos = []

# %%
m.optimizer = 'adadelta', {'step_rate': .1,
                             'momentum': 0.99,
                             'decay': 0.78,
                             'offset': 0.00005}

# %%
t.fit()
# Out:
# n_iter	train_loss	val_loss	test_loss
#
# 50	507.305279914	602.90631216	581.375447329
# 100	135.154773594	151.026373349	132.733125084
# 150	106.61109836	119.21801276	106.534770878
# 200	98.0500930405	109.742958721	98.032852354
# 250	94.5961615758	105.496734051	94.7214440682
# 300	92.4194044624	103.115642464	92.9770891769
# 350	90.8320078114	101.725219435	91.4012756899
# 400	88.7915717829	99.9329077022	89.171550357
# 450	78.3060183637	94.4578819283	77.6171819651
# 500	65.2679089962	72.2047859963	68.6049970028
# 550	47.4773055365	74.2705594744	52.8960855584
# 600	48.4439532753	64.7358632101	44.2735705314
# 650	48.2540442491	68.3453080676	40.0763438791
# 700	30.7552824569	60.6129151939	36.5121167807
# 750	32.0246036499	59.0384125774	31.9583115152
# 800	31.581257453	56.5131513011	33.1878556679
# 850	21.9054827974	39.7018231797	24.9059338493
# 900	20.1677657064	48.8975062629	27.7989282028
# 950	22.2800063977	40.195711072	28.0780444373
# 1000	24.8992231042	48.9120189318	27.0413010837
# 1050	18.9862164662	46.6822042073	19.4369397834
# 1100	19.282514417	37.9887283321	22.3663967783
# 1150	21.7888876197	47.0726852211	20.1382212556
# 1200	13.6017216506	37.5683747951	21.6221387236
# 1250	16.7173927558	42.8474821498	22.5037165548
# 1300	18.0977431493	43.7515334978	23.8152476959
# 1350	17.8597918853	48.0264935029	25.6493696483
# 1400	17.3917726891	46.7661085574	24.8759258092
# 1450	17.2176119799	36.3724993003	18.3250447912
# 1500	16.5961201609	37.6822141992	15.3995154946
# 1550	20.6094230824	39.8657680771	20.0058198317
# 1600	17.2855378728	49.0578385245	20.2909276524
# 1650	13.0046677888	38.9930312821	16.1007708702
# 1700	18.8862297267	31.0683322172	18.3052044039
# 1750	12.1387439274	30.5734916952	16.1004199675
# 1800	13.2652764044	46.0271150236	16.156228414
# 1850	11.5196590203	39.8258795182	15.6305000799
# 1900	15.1515237964	40.9681055307	19.2732773262
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-2640cac80611> in <module>()
# ----> 1 t.fit()
#
# z:\anomalydetection\breze\breze\learn\trainer\trainer.pyc in fit(self)
#     156             Termination will occur when either stop or interrupt is True. During
#     157             each pause, ``.report(info)`` will be executed."""
# --> 158             for i in self.iter_fit():
#     159                 self.report(i)
#     160
#
# z:\anomalydetection\breze\breze\learn\trainer\trainer.pyc in iter_fit(self)
#     177         stripped from any numpy or gnumpy arrays.
#     178         """
# --> 179         for info in self.model.iter_fit(*self.data['train'], info_opt=self.current_info):
#     180             interrupt = self.interrupt(info)
#     181             if self.pause(info) or interrupt:
#
# z:\anomalydetection\breze\breze\learn\base.pyc in iter_fit(self, X, W, info_opt)
#     471         opt = self._make_optimizer(self._f_loss, self._f_dloss, args, info=info_opt)
#     472
# --> 473         for i, info in enumerate(opt):
#     474             yield info
#     475
#
# z:\anomalydetection\climin\climin\base.pyc in __iter__(self)
#      81
#      82     def __iter__(self):
# ---> 83         for info in self._iterate():
#      84             yield self.extended_info(**info)
#      85
#
# z:\anomalydetection\climin\climin\adadelta.pyc in _iterate(self)
#     111             self.wrt -= step1
#     112
# --> 113             gradient = self.fprime(self.wrt, *args, **kwargs)
#     114
#     115             self.gms = (d * self.gms) + (1 - d) * gradient ** 2
#
# z:\anomalydetection\theano_surbarn\theano\theano\compile\function_module.pyc in __call__(self, *args, **kwargs)
#     602         t0_fn = time.time()
#     603         try:
# --> 604             outputs = self.fn()
#     605         except Exception:
#     606             if hasattr(self.fn, 'position_of_error'):
#
# z:\anomalydetection\theano_surbarn\theano\theano\scan_module\scan_op.pyc in rval(p, i, o, n, allow_gc)
#     840         def rval(p=p, i=node_input_storage, o=node_output_storage, n=node,
#     841                  allow_gc=allow_gc):
# --> 842             r = p(n, [x[0] for x in i], o)
#     843             for o in node.outputs:
#     844                 compute_map[o][0] = True
#
# z:\anomalydetection\theano_surbarn\theano\theano\scan_module\scan_op.pyc in <lambda>(node, args, outs)
#     829                         args,
#     830                         outs,
# --> 831                         self, node)
#     832         except (ImportError, theano.gof.cmodule.MissingGXX):
#     833             p = self.execute
#
# C:\Users\msoelch.BRML\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.7-64\scan_perform\scan_perform.pyd in theano.scan_module.scan_perform.perform (C:\Users\msoelch.BRML\AppData\Local\Theano\compiledir_Windows-7-6.1.7601-SP1-Intel64_Family_6_Model_60_Stepping_3_GenuineIntel-2.7.7-64\scan_perform\mod.cpp:3613)()
#
# z:\anomalydetection\theano_surbarn\theano\theano\gof\op.pyc in rval(p, i, o, n)
#     757             # default arguments are stored in the closure of `rval`
#     758             def rval(p=p, i=node_input_storage, o=node_output_storage, n=node):
# --> 759                 r = p(n, [x[0] for x in i], o)
#     760                 for o in node.outputs:
#     761                     compute_map[o][0] = True
#
# z:\anomalydetection\theano_surbarn\theano\theano\tensor\blas.pyc in perform(self, node, inp, out)
#    1929         z, = out
#    1930         try:
# -> 1931             z[0] = numpy.asarray(scalar * numpy.dot(x, y))
#    1932         except ValueError as e:
#    1933             # The error raised by numpy has no shape information, we
#
# KeyboardInterrupt:

# %%
max_passes = 100000
max_minutes = 60
batches_per_pass = int(math.ceil(float(X.shape[1]) / m.batch_size)) if m.batch_size is not None else 1
pause = climin.stops.ModuloNIterations(batches_per_pass * 1)
#pause = climin.stops.ModuloNIterations(1)

stop = climin.stops.Any([
    climin.stops.TimeElapsed(max_minutes * 60),
    climin.stops.Patience('val_loss', 1000, grow_factor=1.1, threshold=0.0001),
    #climin.stops.not_better_than_after(30, 100),
])
    
start = time.time()
# Set up a nice printout.
header = '#', 'seconds', 'loss', 'val loss', 'std mean'
print '\t'.join(header)


for i, info in enumerate(m.powerfit((X, M), (VX, VM), stop, pause, True)):
    info['loss'] = float(info['loss'])
    info['val_loss'] = float(info['val_loss'])  
    #info['test_loss'] = float(ma.scalar(test_score()))
    
    info.update({
        'time': time.time() - start,
        'std_mean': 0 #MyStorn.fixed_std.get_value()[0], 
        #'std_mean': m.parameters[m.vae.gen.std].mean(),
    })
    template = '\t'.join(
        ['%(n_iter)i', '%(time)g', '%(loss)g', '%(val_loss)g %(std_mean)g'])
    row = template % info
    print row

    filtered_info = dict(
        (k, v) for k, v in info.items()
        if (not isinstance(v, (np.ndarray, gp.garray)) or v.size <= 1) and k not in ('args', 'kwargs'))
        #if (not isinstance(v, (np.ndarray, )) or v.size <= 1) and k not in ('args', 'kwargs'))

    for key in filtered_info:
        if isinstance(filtered_info[key], np.float32):
            filtered_info[key] = float(filtered_info[key])
    filtered_info['max_grad'] = np.sqrt((info['gradient'] **
 2).sum())
    infos.append(filtered_info)
# Out:
# z:\anomalydetection\theano_surbarn\theano\theano\scan_module\scan_perform_ext.py:134: RuntimeWarning: numpy.ndarray size changed, may indicate binary incompatibility
#   from scan_perform.scan_perform import *
# z:\anomalydetection\climin\climin\util.py:150: UserWarning: Argument named offset is not expected by <class 'climin.rmsprop.RmsProp'>
#   % (i, klass))
# #	seconds	loss	val loss	std mean
# 4	152.702	25022.5	24970.8 0
# 8	173.01	11811.2	12196.4 0
# 12	193.943	5946.75	6207.21 0
# 16	214.603	2985.63	3153.58 0
# 20	235.134	1453.69	1621.55 0
# 24	255.638	862.226	1030.86 0
# 28	277.21	759.163	893.377 0
# 32	297.713	657.266	784.942 0
# 36	318.707	576.848	691.29 0
# 40	339.337	521.176	627.975 0
# 44	359.866	466.818	558.284 0
# 48	380.082	427.011	499.71 0
# 52	400.265	333.733	386.362 0
# 56	420.72	260.818	301.185 0
# 60	441.154	232.201	255.772 0
# 64	461.33	224.643	249.603 0
# 68	481.46	193.635	214.971 0
# 72	501.674	175.793	194.856 0
# 76	522.006	174.041	192.341 0
# 80	542.399	162.732	182.046 0
# 84	562.939	164.299	179.366 0
# 88	583.327	163.445	178.116 0
# 92	603.476	140.577	156.167 0
# 96	623.676	141.583	156.868 0
# 100	644.01	149.082	163.876 0

# %%
f_loss = m.function(['inpt', 'imp_weight'], 'loss')

# %%
# Recover best parameters.
m.parameters.data[...] = info['best_pars']

# %%
def f(x):
    x = np.array(x).astype('float32')
    MyStorn.fixed_std.set_value(np.array([x]))
    return m.estimate_nll(VX)

# %%
cands = np.linspace(1e-8, .1, 20)
bounds = (f(i) for i in cands)

best, best_cand = float('inf'), 0
for bound, cand in itertools.izip(bounds, cands):
    print bound, cand
    if bound < best:
        best, best_cand = bound, cand
print '-->', best_cand, best
# Out:
# 162609.816609 1e-08
# 100.170732671
#  0.00526316736842
# 8.24755862671
#  0.0105263247368
# -7.78414540211
#  0.0157894821053
# -11.8354169919
#  0.0210526394737
# -14.0495259145
#  0.0263157968421
# -13.91693068
#  0.0315789542105
# -13.7560897879
#  0.0368421115789
# -13.7009402357
#  0.0421052689474
# -13.1899071667
#  0.0473684263158
# -12.6934804571
#  0.0526315836842
# -12.2687090177
#  0.0578947410526
# -11.8073841129
#  0.0631578984211
# -11.3365647873
#  0.0684210557895
# -10.9142532721
#  0.0736842131579
# -10.5903202395
#  0.0789473705263
# -10.2241633546
#  0.0842105278947
# -9.78696435685
#  0.0894736852632
# -9.48017858277
#  0.0947368426316
# -9.10603178534
#  0.1
# --> 0.0263157968421 -14.0495259145

# %%
MyStorn.fixed_std.set_value(np.array([best_cand]))

# %% [markdown]
# Evaluation
# ---
#
# The values for the training/validation do *not* respect the importance weights.

# %%
print 'Bound %.2f    NLL estimate %g for training' % (f_loss(X, M), m.estimate_nll(X, 100))
print 'Bound %.2f    NLL estimate %g for validation' % (f_loss(VX, VM), m.estimate_nll(VX, 100))
print 'Bound %.2f    NLL estimate %g for testing' % (f_loss(tx[0][:, np.newaxis], np.ones_like(tx[0][:, np.newaxis, :1])), m.estimate_nll(tx[0][:, np.newaxis], 5))
# Out:
# Bound -19.59    NLL estimate -14.9755 for training
# Bound -16.95    NLL estimate -12.2996 for validation
# Bound -19.51    NLL estimate -19.8671 for testing

# %% [markdown]
# ## Learning curves

# %%
start = 150
plt.plot([(i['loss']) for i in infos[start:]])
plt.plot([i['val_loss'] for i in infos[start:]])
#plt.plot([i['max_grad'] / 200. for i in infos[200:]])

# %% [markdown]
# ## Sampling

# %%
prefix_length = 80
sample_length = 50
x = np.concatenate([VX[:, :1]] * 50, axis=1)
S = m.sample(sample_length, x[:prefix_length], visible_map=True)

# %%
plt.plot(S[:, 0, 0],S[:, 0, 1])
plt.plot(VX[:,0,0], VX[:,0,1])
#plt.plot(VX.reshape((-1,7))[:,0], VX.reshape((-1,7))[:,1])

# %%
angle_idxs = range(7)
sample_idx = 0
xs = np.arange(prefix_length + sample_length - 1)

fig, axs = plt.subplots(7, figsize=(16, 25))

#axs = list(itertools.chain(*axs))
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)
    
    _ = ax.plot(xs[prefix_length:], S[:, :, i], 'k', alpha=.2)
    _ = ax.axhline(0)
    _ = ax.plot(VX[:, 0, i], label='stimulus')

axs[-1].plot([0, 0], [0, 0], 'k', label='sample')
axs[-1].set_ylim([-100, -99])
axs[-1].set_xlim([-100, -99])
axs[-1].legend(loc=0)

#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

#plt.savefig('/Users/bayerj/Desktop/stimulus-sampling.pdf', bbox_inches='tight')

# %% [markdown]
# ## Prediction

# %% [markdown]
# ### Probabilistic

# %%
rng = T.shared_randomstreams.RandomStreams()
predict_expr_noisy = theano.clone(m.vae.output, 
                            {m.vae.sample: rng.normal(m.vae.sample.shape)})
f_predict_noisy = m.function(['inpt'], predict_expr_noisy)

# %%
x = tx[0][:, np.newaxis]
ys = [f_predict_noisy(x)[:, :1, :49] for i in range(10)]
y = np.mean(ys, axis=0)

# %%
print 'approx prob prediction', ((y - x) ** 2).mean(0).sum()

# %% [markdown]
# ### Latent Mode

# %%
f_predict = m.function(['inpt'], 'output', givens={m.vae.sample: T.zeros_like(m.vae.sample)})

# %%
x = tx[0][:, np.newaxis]
y = f_predict(x)[:, :1, :49]

# %%
print 'map prediction', ((y - x) ** 2).mean(0).sum()

# %%
fig, axs = plt.subplots(2, 2, figsize=(16, 16))

axs = list(itertools.chain(*axs))[:49]
for i, ax in enumerate(axs):
    ax.plot(x[:, 0, [i]], label='true', linewidth=1)
    ax.plot(y[:, 0, [i]], label='predicted', linewidth=1)
    ax.plot(abs(x - y)[:, 0, [i]] - 5, 'k.', label='|residual|')
    ax.set_ylim([-5, 3])
    #ax.set_title('dimension %i' % i)
    ax.set_yticks([])
    ax.set_xticks([])

axs[0].legend()

# %% [markdown]
# Reconstruction
# ---

# %%
f_reconstruct = m.function(['inpt'], 'output')

# %%
R = f_reconstruct(X)[:, :, :49]

# %%
fig, axs = plt.subplots(7, 7, figsize=(16, 16))
start, stop = 0, -1

axs = list(itertools.chain(*axs))[:49]
for i, ax in enumerate(axs):
    ax.plot(X[start:stop, 0, [i]], label='truth', linewidth=1)
    ax.plot(R[start:stop, 0, [i]], label='reconstruction', linewidth=1)
    #ax.plot(noisy[start:stop, 0, [i]], label='noisy', linewidth=1)
    #ax.plot(denoised[start:stop, 0, [i]], label='denoised', linewidth=2, color='k')
    #ax.plot(abs(noisy[:, :, :49] - X)[:, 0, [i]] - 5, 'r.', label='|residual noisy|')
    #ax.plot(abs(denoised[:, :, :49] - X)[:, 0, [i]] - 5, 'b.', label='|residual denoised|')
    ax.set_ylim([-5, 3])
    #ax.set_title('dimension %i' % i)
    ax.set_yticks([])
    ax.set_xticks([])

axs[0].legend()

# %% [markdown]
# Missing Value Imputation
# ---

# %%
sample_map = m.vae.latent[:, :, :n_latents]
gen_inpt = T.concatenate([sample_map, m.vae.condition], axis=2)

map_recons_exprs = theano.clone(m.exprs['output'], 
                                {m.vae.sample: sample_map})
f_map_recons = m.function(['inpt'], map_recons_exprs)

# %%
def map_impute(start, to_impute_idxs, n_steps=10):
    denoised = start.copy()
    denoised[to_impute_idxs] = np.random.standard_normal(denoised[to_impute_idxs].shape)
    noisy = denoised.copy()
    
    for i in range(n_steps):
        reconstructed = f_map_recons(denoised)
        denoised[to_impute_idxs] = reconstructed[:, :, :49][to_impute_idxs]
    return noisy, denoised

# %%
clean = VX[:, :1]
mask = np.zeros_like(clean).astype('uint8')
mask[30:40][...] = 1
to_impute_idxs = np.where(mask)
#noised[to_impute_idxs] = np.random.standard_normal(noised[to_impute_idxs].shape) * 1

noisy, denoised = map_impute(clean, to_impute_idxs, 100)

# %%
angle_idxs = range(49)
sample = 0

fig, axs = plt.subplots(7, 7, figsize=(16, 9))

xs = np.arange(X.shape[0])
axs = list(itertools.chain(*axs))
for i, ax in zip(angle_idxs, axs):
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_frame_on(False)

    _ = ax.plot(xs[to_impute_idxs[0]], noisy[to_impute_idxs[0], 0, i], 'r-', linewidth=1, label='noisy', alpha=.3)
    _ = ax.plot(xs[to_impute_idxs[0]], denoised[to_impute_idxs[0], 0, i], 'k-', linewidth=1, label='imputed')
    _ = ax.plot(xs, clean[:, 0, i], 'b-', linewidth=1, label='truth', alpha=.5)

axs[-1].set_ylim([-100, -99])
axs[-1].set_xlim([-100, -99])
axs[-1].legend(loc=0)

#axs[1][0].set_title('original data')
#axs[1][1].set_title('denoised data')

plt.savefig('/Users/bayerj/Desktop/imputed.pdf', bbox_inches='tight')

# %% [markdown]
# Latent trajectories
# ---

# %%
f_latent = m.function(['inpt'], m.vae.latent)

# %%
L = f_latent(VX[:, :10])
Lm, Ls = L[:, :, :m.n_latent], L[:, :, m.n_latent:]

# %%
fig, axs = plt.subplots(5, 5, figsize=(16, 16))

def plot_latent_trajectory(ax, mean, vr):
        ax.plot(mean, 'k+-')
        #ax.plot(mean + std, 'k--')
        #ax.plot(mean - std, 'k--')
        
        x = np.arange(mean.shape[0])
        ax.fill(
            np.concatenate([x, x[::-1]]),
            np.concatenate([mean - vr, (mean + vr)[::-1]]),
            alpha=.5, fc='b', ec='None')
        ax.set_xticks([])
        ax.set_yticks([-1, 0, 1])

axs_flat = itertools.chain(*axs)

#active = [6, 7, 9, 20, 26, 32, 37, 60]
active = range(64)

for i, ax in enumerate(axs_flat):
    try:
        plot_latent_trajectory(ax, Lm[:, 0, i], Ls[:, 0, i])
    except IndexError:
        break
